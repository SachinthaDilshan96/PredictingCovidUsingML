# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv("Covid Dataset.csv")

# %%
data
# Out:
#         ID Breathing Problem Fever Dry Cough Sore throat Running Nose Asthma  \
# 0        1               Yes   Yes       Yes         Yes          Yes     No
# 1        2               Yes   Yes       Yes         Yes           No    Yes
# 2        3               Yes   Yes       Yes         Yes          Yes    Yes
# 3        4               Yes   Yes       Yes          No           No    Yes
# 4        5               Yes   Yes       Yes         Yes          Yes     No
# ...    ...               ...   ...       ...         ...          ...    ...
# 5429  5430               Yes   Yes        No         Yes          Yes    Yes
# 5430  5431               Yes   Yes       Yes          No          Yes    Yes
# 5431  5432               Yes   Yes       Yes          No           No     No
# 5432  5433               Yes   Yes       Yes          No          Yes     No
# 5433  5434               Yes   Yes       Yes          No          Yes    Yes
#
#      Chronic Lung Disease Headache Heart Disease  ... Fatigue   \
# 0                      No       No            No  ...      Yes
# 1                     Yes      Yes            No  ...      Yes
# 2                     Yes      Yes            No  ...      Yes
# 3                      No       No           Yes  ...       No
# 4                     Yes      Yes           Yes  ...       No
# ...                   ...      ...           ...  ...      ...
# 5429                  Yes       No            No  ...      Yes
# 5430                   No      Yes            No  ...      Yes
# 5431                   No       No           Yes  ...       No
# 5432                   No      Yes           Yes  ...       No
# 5433                   No      Yes            No  ...      Yes
#
#      Gastrointestinal  Abroad travel Contact with COVID Patient  \
# 0                  Yes            No                        Yes
# 1                   No            No                         No
# 2                  Yes           Yes                         No
# 3                   No           Yes                         No
# 4                  Yes            No                        Yes
# ...                ...           ...                        ...
# 5429               Yes            No                         No
# 5430                No            No                         No
# 5431                No            No                         No
# 5432                No            No                         No
# 5433                No            No                         No
#
#      Attended Large Gathering Visited Public Exposed Places  \
# 0                          No                           Yes
# 1                         Yes                           Yes
# 2                          No                            No
# 3                         Yes                           Yes
# 4                          No                           Yes
# ...                       ...                           ...
# 5429                       No                            No
# 5430                       No                            No
# 5431                       No                            No
# 5432                       No                            No
# 5433                       No                            No
#
#      Family working in Public Exposed Places Wearing Masks  \
# 0                                        Yes            No
# 1                                         No            No
# 2                                         No            No
# 3                                         No            No
# 4                                         No            No
# ...                                      ...           ...
# 5429                                      No            No
# 5430                                      No            No
# 5431                                      No            No
# 5432                                      No            No
# 5433                                      No            No
#
#      Sanitization from Market COVID-19
# 0                          No      Yes
# 1                          No      Yes
# 2                          No      Yes
# 3                          No      Yes
# 4                          No      Yes
# ...                       ...      ...
# 5429                       No      Yes
# 5430                       No      Yes
# 5431                       No       No
# 5432                       No       No
# 5433                       No       No
#
# [5434 rows x 22 columns]

# %%
#check for missing values
data.isna().sum()
# Out:
# ID                                         0
# Breathing Problem                          0
# Fever                                      0
# Dry Cough                                  0
# Sore throat                                0
# Running Nose                               0
# Asthma                                     0
# Chronic Lung Disease                       0
# Headache                                   0
# Heart Disease                              0
# Diabetes                                   0
# Hyper Tension                              0
# Fatigue                                    0
# Gastrointestinal                           0
# Abroad travel                              0
# Contact with COVID Patient                 0
# Attended Large Gathering                   0
# Visited Public Exposed Places              0
# Family working in Public Exposed Places    0
# Wearing Masks                              0
# Sanitization from Market                   0
# COVID-19                                   0
# dtype: int64

# %%
#separte the Features and Target variable
X=data.iloc[:,0:21]
Y=data.iloc[:,21:22]

# %%
#split the dataset into train and test sets
x,xtest,y,ytest=train_test_split(X,Y,train_size=0.8)

# %% [markdown]
# # Exploratory Analysis

# %%
def barPerc(df,xVar,ax):
    '''
    barPerc(): Add percentage for hues to bar plots
    args:
        df: pandas dataframe
        xVar: (string) X variable 
        ax: Axes object (for Seaborn Countplot/Bar plot or
                         pandas bar plot)
    '''
    # 1. how many X categories
    ##   check for NaN and remove
    numX=len([x for x in df[xVar].unique() if x==x])

    # 2. The bars are created in hue order, organize them
    bars = ax.patches
    ## 2a. For each X variable
    for ind in range(numX):
        ## 2b. Get every hue bar
        ##     ex. 8 X categories, 4 hues =>
        ##    [0, 8, 16, 24] are hue bars for 1st X category
        hueBars=bars[ind:][::numX]
        ## 2c. Get the total height (for percentages)
        total = sum([x.get_height() for x in hueBars])

        # 3. Print the percentage on the bars
        for bar in hueBars:
            ax.text(bar.get_x() + bar.get_width()/2.,
                    bar.get_height(),
                    f'{bar.get_height()/total:.0%}',
                    ha="center",va="bottom")

# %%
#plt.rcParams.update({'figure.figsize':(7.5,5), 'figure.dpi':100})  
fig, axs = plt.subplots(1, 4, figsize=(21, 4))
sns.countplot(ax=axs[0],x='Breathing Problem',hue='Dry Cough',data=x)
barPerc(x,'Breathing Problem',axs[0])
sns.countplot(ax=axs[1],x='Breathing Problem',hue='Sore throat',data=x)
barPerc(x,'Breathing Problem',axs[1])
sns.countplot(ax=axs[2],x='Breathing Problem',hue='Running Nose',data=x)
barPerc(x,'Breathing Problem',axs[2])
sns.countplot(ax=axs[3],x='Breathing Problem',hue='Running Nose',data=x)
barPerc(x,'Breathing Problem',axs[3])

# %%
fig, axs = plt.subplots(2, 2, figsize=(17, 7))
sns.countplot(ax=axs[0][0],x='Chronic Lung Disease',hue='Dry Cough',data=x)
barPerc(x,'Chronic Lung Disease',axs[0][0])
sns.countplot(ax=axs[0][1],x='Chronic Lung Disease',hue='Breathing Problem',data=x)
barPerc(x,'Chronic Lung Disease',axs[0][1])
sns.countplot(ax=axs[1][0],x='Chronic Lung Disease',hue='Dry Cough',data=x)
barPerc(x,'Chronic Lung Disease',axs[1][0])
sns.countplot(ax=axs[1][1],x='Chronic Lung Disease',hue='Sore throat',data=x)
barPerc(x,'Chronic Lung Disease',axs[1][1])
#sns.countplot(ax=axs[2][0],x='Chronic Lung Disease',hue='Fatigue',data=x)

# %%
fig, axs = plt.subplots(3, 2, figsize=(15, 7))
sns.countplot(ax=axs[0][0],x='Asthma',hue='Dry Cough',data=x)
barPerc(x,'Asthma',axs[0][0])
sns.countplot(ax=axs[0][1],x='Asthma',hue='Breathing Problem',data=x)
barPerc(x,'Asthma',axs[0][1])
sns.countplot(ax=axs[1][0],x='Asthma',hue='Dry Cough',data=x)
barPerc(x,'Asthma',axs[1][0])
sns.countplot(ax=axs[1][1],x='Asthma',hue='Sore throat',data=x)
barPerc(x,'Asthma',axs[1][1])
#sns.countplot(ax=axs[2][0],x='Asthma',hue='Fatigue',data=x)

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5))
sns.countplot(ax=axs[0],x='Fever',hue='Headache',data=x)
barPerc(x,'Fever',axs[0])
sns.countplot(ax=axs[1],x='Chronic Lung Disease',hue='Fever',data=x)
barPerc(x,'Chronic Lung Disease',axs[1])

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 5))
sns.countplot(ax=axs[0],x='Heart Disease',hue='Hyper Tension',data=x)
barPerc(x,'Heart Disease',axs[0])
sns.countplot(ax=axs[1],x='Heart Disease',hue='Fever',data=x)
barPerc(x,'Heart Disease',axs[1])

#sns.countplot(ax=axs[2],x='Heart Disease',hue='Fatigue',data=x)

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 5))
sns.countplot(ax=axs[0],x='Abroad travel',hue='Attended Large Gathering',data=x)
barPerc(x,'Abroad travel',axs[0])
sns.countplot(ax=axs[1],x='Abroad travel',hue='Visited Public Exposed Places',data=x)
barPerc(x,'Abroad travel',axs[1])
sns.countplot(ax=axs[2],x='Abroad travel',hue='Family working in Public Exposed Places',data=x)
barPerc(x,'Abroad travel',axs[2])
plt.legend(loc='upper right', title='Family working in Public\n Exposed Places')

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 10))
sns.countplot(ax=axs[0][0],x='Contact with COVID Patient',hue='Attended Large Gathering',data=x)
barPerc(x,'Contact with COVID Patient',axs[0][0])
sns.countplot(ax=axs[0][1],x='Contact with COVID Patient',hue='Visited Public Exposed Places',data=x)
barPerc(x,'Contact with COVID Patient',axs[0][1])
sns.countplot(ax=axs[1][0],x='Contact with COVID Patient',hue='Family working in Public Exposed Places',data=x)
barPerc(x,'Contact with COVID Patient',axs[1][0])
plt.legend(loc='upper left', title='Family working in Public\n Exposed Places')
sns.countplot(ax=axs[1][1],x='Contact with COVID Patient',hue='Family working in Public Exposed Places',data=x)
barPerc(x,'Contact with COVID Patient',axs[1][1])
# Out:
# No handles with labels found to put in legend.

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
sns.countplot(ax=axs[0],x='Contact with COVID Patient',hue='Wearing Masks',data=x)
sns.countplot(ax=axs[1],x='Contact with COVID Patient',hue='Sanitization from Market',data=x)
# Out:
# <AxesSubplot:xlabel='Contact with COVID Patient', ylabel='count'>

# %%
#compine x and y for further analysis
x['covid']=y
# Out:
# <ipython-input-16-3864b10d8908>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['covid']=y

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 5))
sns.countplot(ax=axs[0],x='covid',hue='Breathing Problem',data=x)
barPerc(x,'covid',axs[0])
sns.countplot(ax=axs[1],x='covid',hue='Asthma',data=x) 
barPerc(x,'covid',axs[1])
sns.countplot(ax=axs[2],x='covid',hue='Headache',data=x)
barPerc(x,'covid',axs[2])

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
temp=x[x['covid']=='Yes']
sns.countplot(ax=axs[0],x='Chronic Lung Disease',hue='Breathing Problem',data=temp)
axs[0].title.set_text('COVID Positive')
barPerc(x,'Chronic Lung Disease',axs[0])
temp=x[x['covid']=='No']
sns.countplot(ax=axs[1],x='Chronic Lung Disease',hue='Breathing Problem',data=temp)
axs[1].title.set_text('COVID Negative')
barPerc(x,'Chronic Lung Disease',axs[1])

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
temp=x[x['covid']=='Yes']
sns.countplot(ax=axs[0],x='Chronic Lung Disease',hue='Asthma',data=temp)
axs[0].title.set_text('COVID Positive')
barPerc(x,'Chronic Lung Disease',axs[0])

temp=x[x['covid']=='No']
sns.countplot(ax=axs[1],x='Chronic Lung Disease',hue='Asthma',data=temp)
axs[1].title.set_text('COVID Negative')
barPerc(x,'Chronic Lung Disease',axs[1])

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
temp=x[x['covid']=='Yes']
sns.countplot(ax=axs[0],x='Chronic Lung Disease',hue='Dry Cough',data=temp)
axs[0].title.set_text('COVID Positive')
barPerc(x,'Chronic Lung Disease',axs[0])

temp=x[x['covid']=='No']
sns.countplot(ax=axs[1],x='Chronic Lung Disease',hue='Dry Cough',data=temp)
axs[1].title.set_text('COVID Negative')
barPerc(x,'Chronic Lung Disease',axs[1])

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
temp=x[x['covid']=='Yes']
sns.countplot(ax=axs[0],x='Heart Disease',hue='Breathing Problem',data=temp)
barPerc(x,'Heart Disease',axs[0])

axs[0].title.set_text('COVID Positive')
temp=x[x['covid']=='No']
sns.countplot(ax=axs[1],x='Heart Disease',hue='Breathing Problem',data=temp)
axs[1].title.set_text('COVID Negative')
barPerc(x,'Heart Disease',axs[1])

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
temp=x[x['covid']=='Yes']
sns.countplot(ax=axs[0],x='Heart Disease',hue='Asthma',data=temp)
axs[0].title.set_text('COVID Positive')
barPerc(x,'Heart Disease',axs[0])

temp=x[x['covid']=='No']
sns.countplot(ax=axs[1],x='Heart Disease',hue='Asthma',data=temp)
axs[1].title.set_text('COVID Negative')
barPerc(x,'Heart Disease',axs[1])

# %%
#meaningless
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
temp=x[x['covid']=='Yes']
sns.countplot(ax=axs[0],x='Attended Large Gathering',hue='Wearing Masks',data=temp)
axs[0].title.set_text('COVID Positive')
temp=x[x['covid']=='No']
sns.countplot(ax=axs[1],x='Attended Large Gathering',hue='Wearing Masks',data=temp)
axs[1].title.set_text('COVID Negative')

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
temp=x[x['covid']=='Yes']
sns.countplot(ax=axs[0],x='Attended Large Gathering',hue='Visited Public Exposed Places',data=temp)
axs[0].title.set_text('COVID Positive')
barPerc(x,'Attended Large Gathering',axs[0])

temp=x[x['covid']=='No']
sns.countplot(ax=axs[1],x='Attended Large Gathering',hue='Visited Public Exposed Places',data=temp)
axs[1].title.set_text('COVID Negative')
barPerc(x,'Attended Large Gathering',axs[1])

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
temp=x[x['covid']=='Yes']
sns.countplot(ax=axs[0],x='Attended Large Gathering',hue='Family working in Public Exposed Places',data=temp)
axs[0].title.set_text('COVID Positive')
barPerc(x,'Attended Large Gathering',axs[0])

temp=x[x['covid']=='No']
sns.countplot(ax=axs[1],x='Attended Large Gathering',hue='Family working in Public Exposed Places',data=temp)
axs[1].title.set_text('COVID Negative')
barPerc(x,'Attended Large Gathering',axs[1])

# %%
fig, axs = plt.subplots(1, 1, figsize=(20, 5))
sns.countplot(x='covid',hue='Contact with COVID Patient',data=x)
barPerc(x,'covid',axs)
#can observe the airborn nature

# %%
fig, axs = plt.subplots(1, 1, figsize=(20, 5))
sns.countplot(x='covid',hue='Abroad travel',data=x)
barPerc(x,'covid',axs)
# Out:
# posx and posy should be finite values
# posx and posy should be finite values

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
temp=x[x['covid']=='Yes']
sns.countplot(ax=axs[0],x='Abroad travel',hue='Attended Large Gathering',data=temp)
axs[0].title.set_text('COVID Positive')
barPerc(x,'Abroad travel',axs[0])

temp=x[x['covid']=='No']
sns.countplot(ax=axs[1],x='Abroad travel',hue='Attended Large Gathering',data=temp)
axs[1].title.set_text('COVID Negative')
barPerc(x,'Abroad travel',axs[1])

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
temp=x[x['covid']=='Yes']
sns.countplot(ax=axs[0],x='Abroad travel',hue='Visited Public Exposed Places',data=temp)
axs[0].title.set_text('COVID Positive')
barPerc(x,'Abroad travel',axs[0])

temp=x[x['covid']=='No']
sns.countplot(ax=axs[1],x='Abroad travel',hue='Visited Public Exposed Places',data=temp)
axs[1].title.set_text('COVID Negative')
barPerc(x,'Abroad travel',axs[1])

# %% [markdown]
# # chi square tests to evalute the correlation
#
# Let H0: There is no Relationship between two variables (Two variables are independent)
#
#     H1: There is a Relationship between two variables (Two variables are not independent)

# %%
#encode values
dic={'Yes':1,'No':0}
for i in x.columns:
    x[i].replace(dic,inplace=True)
for i in xtest.columns:
    xtest[i].replace(dic,inplace=True)
for i in ytest:
    ytest[i].replace(dic,inplace=True)
# Out:
# C:\Users\sachi\anaconda3\lib\site-packages\pandas\core\series.py:4509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
#remove covid and ID from datafram
y=x['covid']
x.drop(['covid'],inplace=True,axis=1)
x.drop(['ID'],inplace=True,axis=1)
xtest.drop(['ID'],inplace=True,axis=1)
# Out:
# C:\Users\sachi\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
from scipy.stats import chi2_contingency
colnames=x.columns
for i in colnames:
    contingency=pd.crosstab(x[i],y)
    print('Contingency table for Covid and ',i)
    print(contingency)
    stat,p,dof,expected=chi2_contingency(contingency)
    alpha=0.05
    if p<= alpha:
        print('Covid and ',i,' are related')
        
    else:
        print('Covid and ',i,' are not  related')
    print("########################################3")
# Out:
# Contingency table for Covid and  Breathing Problem
# covid                0     1
# Breathing Problem
# 0                  642   813
# 1                  199  2693
# Covid and  Breathing Problem  are related
# ########################################3
# Contingency table for Covid and  Fever
# covid    0     1
# Fever
# 0      432   506
# 1      409  3000
# Covid and  Fever  are related
# ########################################3
# Contingency table for Covid and  Dry Cough
# covid        0     1
# Dry Cough
# 0          492   412
# 1          349  3094
# Covid and  Dry Cough  are related
# ########################################3
# Contingency table for Covid and  Sore throat
# covid          0     1
# Sore throat
# 0            616   573
# 1            225  2933
# Covid and  Sore throat  are related
# ########################################3
# Contingency table for Covid and  Running Nose
# covid           0     1
# Running Nose
# 0             372  1604
# 1             469  1902
# Covid and  Running Nose  are not  related
# ########################################3
# Contingency table for Covid and  Asthma
# covid     0     1
# Asthma
# 0       519  1819
# 1       322  1687
# Covid and  Asthma  are related
# ########################################3
# Contingency table for Covid and  Chronic Lung Disease
# covid                   0     1
# Chronic Lung Disease
# 0                     397  1896
# 1                     444  1610
# Covid and  Chronic Lung Disease  are related
# ########################################3
# Contingency table for Covid and  Headache
# covid       0     1
# Headache
# 0         401  1774
# 1         440  1732
# Covid and  Headache  are not  related
# ########################################3
# Contingency table for Covid and  Heart Disease
# covid            0     1
# Heart Disease
# 0              470  1856
# 1              371  1650
# Covid and  Heart Disease  are not  related
# ########################################3
# Contingency table for Covid and  Diabetes
# covid       0     1
# Diabetes
# 0         484  1783
# 1         357  1723
# Covid and  Diabetes  are related
# ########################################3
# Contingency table for Covid and  Hyper Tension
# covid            0     1
# Hyper Tension
# 0              513  1711
# 1              328  1795
# Covid and  Hyper Tension  are related
# ########################################3
# Contingency table for Covid and  Fatigue
# covid       0     1
# Fatigue
# 0         364  1737
# 1         477  1769
# Covid and  Fatigue   are related
# ########################################3
# Contingency table for Covid and  Gastrointestinal
# covid                0     1
# Gastrointestinal
# 0                  441  1877
# 1                  400  1629
# Covid and  Gastrointestinal   are not  related
# ########################################3
# Contingency table for Covid and  Abroad travel
# covid            0     1
# Abroad travel
# 0              841  1528
# 1                0  1978
# Covid and  Abroad travel  are related
# ########################################3
# Contingency table for Covid and  Contact with COVID Patient
# covid                         0     1
# Contact with COVID Patient
# 0                           719  1463
# 1                           122  2043
# Covid and  Contact with COVID Patient  are related
# ########################################3
# Contingency table for Covid and  Attended Large Gathering
# covid                       0     1
# Attended Large Gathering
# 0                         790  1545
# 1                          51  1961
# Covid and  Attended Large Gathering  are related
# ########################################3
# Contingency table for Covid and  Visited Public Exposed Places
# covid                            0     1
# Visited Public Exposed Places
# 0                              502  1598
# 1                              339  1908
# Covid and  Visited Public Exposed Places  are related
# ########################################3
# Contingency table for Covid and  Family working in Public Exposed Places
# covid                                      0     1
# Family working in Public Exposed Places
# 0                                        631  1914
# 1                                        210  1592
# Covid and  Family working in Public Exposed Places  are related
# ########################################3
# Contingency table for Covid and  Wearing Masks
# covid            0     1
# Wearing Masks
# 0              841  3506
# Covid and  Wearing Masks  are not  related
# ########################################3
# Contingency table for Covid and  Sanitization from Market
# covid                       0     1
# Sanitization from Market
# 0                         841  3506
# Covid and  Sanitization from Market  are not  related
# ########################################3

# %%
from sklearn.feature_selection import chi2

xtemp=x.iloc[:,0:18]
resultant = pd.DataFrame(data=[(0 for i in range(len(xtemp.columns))) for i in range(len(xtemp.columns))], 
                         columns=list(xtemp.columns))
resultant.set_index(pd.Index(list(xtemp.columns)), inplace = True)

# %%
import numpy as np

for i in list(xtemp.columns):
    for j in list(xtemp.columns):
        if i != j:
            chi2_val, p_val = chi2(np.array(xtemp[i]).reshape(-1, 1), np.array(xtemp[j]).reshape(-1, 1))
            resultant.loc[i,j] = p_val
print(resultant)
# Out:
#                                          Breathing Problem         Fever  \
# Breathing Problem                             0.000000e+00  3.531138e-04
# Fever                                         4.121637e-03  0.000000e+00
# Dry Cough                                     9.815967e-06  8.387978e-05
# Sore throat                                   2.259659e-25  4.388326e-30
# Running Nose                                  7.337684e-03  6.134000e-04
# Asthma                                        1.975275e-03  8.508185e-04
# Chronic Lung Disease                          2.075941e-06  2.216351e-01
# Headache                                      1.238544e-02  8.217705e-02
# Heart Disease                                 2.568812e-04  9.467124e-02
# Diabetes                                      1.301780e-03  2.924607e-03
# Hyper Tension                                 1.556114e-02  4.874554e-04
# Fatigue                                       9.370328e-01  1.381414e-03
# Gastrointestinal                              6.536165e-05  7.798061e-01
# Abroad travel                                 6.023750e-09  2.823745e-12
# Contact with COVID Patient                    3.660498e-23  2.425187e-13
# Attended Large Gathering                      4.379467e-23  9.219796e-05
# Visited Public Exposed Places                 9.392332e-03  9.126072e-01
# Family working in Public Exposed Places       2.909592e-01  2.559534e-01
#
#                                             Dry Cough   Sore throat  \
# Breathing Problem                        2.034863e-08  1.115839e-30
# Fever                                    6.167340e-05  4.425055e-24
# Dry Cough                                0.000000e+00  2.352230e-10
# Sore throat                              3.678816e-13  0.000000e+00
# Running Nose                             1.175757e-01  8.387928e-02
# Asthma                                   2.428018e-05  4.174553e-04
# Chronic Lung Disease                     3.888071e-01  2.224644e-02
# Headache                                 1.090266e-01  4.156565e-01
# Heart Disease                            8.132268e-03  8.726549e-01
# Diabetes                                 8.949433e-01  8.468823e-01
# Hyper Tension                            4.224653e-03  4.759621e-02
# Fatigue                                  6.180586e-02  3.050113e-01
# Gastrointestinal                         3.261609e-01  4.864011e-01
# Abroad travel                            7.866745e-58  6.152118e-24
# Contact with COVID Patient               1.849215e-08  5.692683e-18
# Attended Large Gathering                 1.193223e-06  4.821886e-27
# Visited Public Exposed Places            1.205528e-03  9.877017e-04
# Family working in Public Exposed Places  1.913614e-16  2.197042e-08
#
#                                          Running Nose        Asthma  \
# Breathing Problem                            0.021410  1.465778e-02
# Fever                                        0.018266  3.461411e-02
# Dry Cough                                    0.289802  8.666743e-03
# Sore throat                                  0.179955  1.185303e-02
# Running Nose                                 0.000000  3.273897e-01
# Asthma                                       0.286729  0.000000e+00
# Chronic Lung Disease                                                3.324301e-02
# Headache                                                            5.897953e-01
# Heart Disease                                                       2.548589e-01
# Diabetes                                                            1.104834e-05
# Hyper Tension                                                       1.373306e-02
# Fatigue                                                             2.644500e-01
# Gastrointestinal                                                    1.137182e-01
# Abroad travel                                                       7.484623e-12
# Contact with COVID Patient                                          5.263439e-01
# Attended Large Gathering                                            3.805064e-03
# Visited Public Exposed Places                                       1.636019e-01
# Family working in Public Exposed Places                             0.000000e+00

# %%
fig = plt.figure(figsize=(20,20))
sns.heatmap(resultant, annot=True, cmap='Blues')
plt.title('Chi-Square Test Results')
plt.show()

# %%
resultant[resultant<0.05]
# Out:
#                                          Breathing Problem         Fever  \
# Breathing Problem                             0.000000e+00  3.531138e-04
# Fever                                         4.121637e-03  0.000000e+00
# Dry Cough                                     9.815967e-06  8.387978e-05
# Sore throat                                   2.259659e-25  4.388326e-30
# Running Nose                                  7.337684e-03  6.134000e-04
# Asthma                                        1.975275e-03  8.508185e-04
# Chronic Lung Disease                          2.075941e-06           NaN
# Headache                                      1.238544e-02           NaN
# Heart Disease                                 2.568812e-04           NaN
# Diabetes                                      1.301780e-03  2.924607e-03
# Hyper Tension                                 1.556114e-02  4.874554e-04
# Fatigue                                                NaN  1.381414e-03
# Gastrointestinal                              6.536165e-05           NaN
# Abroad travel                                 6.023750e-09  2.823745e-12
# Contact with COVID Patient                    3.660498e-23  2.425187e-13
# Attended Large Gathering                      4.379467e-23  9.219796e-05
# Visited Public Exposed Places                 9.392332e-03           NaN
# Family working in Public Exposed Places                NaN           NaN
#
#                                             Dry Cough   Sore throat  \
# Breathing Problem                        2.034863e-08  1.115839e-30
# Fever                                    6.167340e-05  4.425055e-24
# Dry Cough                                0.000000e+00  2.352230e-10
# Sore throat                              3.678816e-13  0.000000e+00
# Running Nose                                      NaN           NaN
# Asthma                                   2.428018e-05  4.174553e-04
# Chronic Lung Disease                              NaN  2.224644e-02
# Headache                                          NaN           NaN
# Heart Disease                            8.132268e-03           NaN
# Diabetes                                          NaN           NaN
# Hyper Tension                            4.224653e-03  4.759621e-02
# Fatigue                                           NaN           NaN
# Gastrointestinal                                  NaN           NaN
# Abroad travel                            7.866745e-58  6.152118e-24
# Contact with COVID Patient               1.849215e-08  5.692683e-18
# Attended Large Gathering                 1.193223e-06  4.821886e-27
# Visited Public Exposed Places            1.205528e-03  9.877017e-04
# Family working in Public Exposed Places  1.913614e-16  2.197042e-08
#
#                                          Running Nose        Asthma  \
# Breathing Problem                            0.021410  1.465778e-02
# Fever                                        0.018266  3.461411e-02
# Dry Cough                                         NaN  8.666743e-03
# Sore throat                                       NaN  1.185303e-02
# Running Nose                                 0.000000           NaN
# Asthma                                            NaN  0.000000e+00
# Chronic Lung Disease                              NaN           NaN
# Headache                                     0.002817           NaN
# Heart Disease                                0.004673  6.991549e-04
# Diabetes                                          NaN           NaN
# Hyper Tension                                     NaN           NaN
# Fatigue                                           NaN           NaN
# Gastrointestinal                                  NaN  5.252587e-06
# Abroad travel                                     NaN  1.901949e-03
# Contact with COVID Patient                        NaN           NaN
# Attended Large Gathering                     0.005075  8.487028e-03
# Visited Public Exposed Places                     NaN           NaN
# Family working in Public Exposed Places      0.006183  1.643838e-07
#
#                                          Chronic Lung Disease      Headache  \
# Breathing Problem                                    0.000157  4.080071e-02
# Fever                                                     NaN           NaN
# Dry Cough                                                 NaN           NaN
# Sore throat                                               NaN           NaN
# Running Nose                                              NaN  4.411172e-03
# Asthma                                                    NaN           NaN
# Chronic Lung Disease                                 0.000000           NaN
# Headache                                                  NaN  0.000000e+00
# Heart Disease                                             NaN  1.093965e-02
# Diabetes                                                  NaN           NaN
# Hyper Tension                                             NaN  9.449601e-22
# Fatigue                                              0.024391  3.703259e-03
# Gastrointestinal                                     0.011658  6.300980e-07
# Abroad travel                                        0.000045  2.265740e-02
# Contact with COVID Patient                           0.003932  8.209063e-06
# Attended Large Gathering                                  NaN  4.613977e-17
# Visited Public Exposed Places                        0.000292           NaN
# Family working in Public Exposed Places              0.024891           NaN
#
#                                          Heart Disease  Diabetes  \
# Breathing Problem                             0.003840  0.009992
# Fever                                              NaN       NaN
# Dry Cough                                          NaN       NaN
# Sore throat                                        NaN       NaN
# Running Nose                                  0.009127       NaN
# Asthma                                        0.000677       NaN
# Chronic Lung Disease                               NaN       NaN
# Headache                                      0.013869       NaN
# Heart Disease                                 0.000000  0.049920
# Diabetes                                           NaN  0.000000
# Hyper Tension                                      NaN  0.020900
# Fatigue                                       0.000265  0.035822
# Gastrointestinal                                   NaN       NaN
# Abroad travel                                      NaN  0.020336
# Contact with COVID Patient                         NaN  0.001970
# Attended Large Gathering                      0.038016  0.005121
# Visited Public Exposed Places                 0.000032  0.000379
# Family working in Public Exposed Places            NaN  0.000003
#
#                                          Hyper Tension  Fatigue   \
# Breathing Problem                                  NaN       NaN
# Fever                                     2.351681e-02  0.032586
# Dry Cough                                          NaN       NaN
# Sore throat                                        NaN       NaN
# Running Nose                                       NaN       NaN
# Asthma                                             NaN       NaN
# Chronic Lung Disease                               NaN  0.018697
# Headache                                  2.627152e-21  0.003146
# Heart Disease                                      NaN  0.000124
# Diabetes                                  1.969985e-02  0.029236
# Hyper Tension                             0.000000e+00       NaN
# Fatigue                                            NaN  0.000000
# Gastrointestinal                          5.381412e-04       NaN
# Abroad travel                                      NaN  0.000628
# Contact with COVID Patient                         NaN       NaN
# Attended Large Gathering                           NaN       NaN
# Visited Public Exposed Places                      NaN       NaN
# Family working in Public Exposed Places   8.388682e-03       NaN
#
#                                          Gastrointestinal   Abroad travel  \
# Breathing Problem                                 0.001560   5.162681e-06
# Fever                                                  NaN   1.102435e-05
# Dry Cough                                              NaN   4.064640e-23
# Sore throat                                            NaN   8.814849e-13
# Running Nose                                           NaN            NaN
# Asthma                                            0.000005   2.037250e-03
# Chronic Lung Disease                              0.012118   5.932230e-05
# Headache                                          0.000001   2.897341e-02
# Heart Disease                                          NaN            NaN
# Diabetes                                               NaN   2.323209e-02
# Hyper Tension                                     0.000699            NaN
# Fatigue                                                NaN   1.282359e-03
# Gastrointestinal                                  0.000000   1.944435e-06
# Abroad travel                                     0.000002   0.000000e+00
# Contact with COVID Patient                             NaN   1.059139e-03
# Attended Large Gathering                               NaN   3.231421e-08
# Visited Public Exposed Places                     0.005391   2.799064e-03
# Family working in Public Exposed Places                NaN   1.266594e-12
#
#                                          Contact with COVID Patient  \
# Breathing Problem                                      5.738867e-16
# Fever                                                  1.576108e-06
# Dry Cough                                              2.935323e-04
# Sore throat                                            1.807913e-10
# Running Nose                                                    NaN
# Asthma                                                          NaN
# Chronic Lung Disease                                   3.116737e-03
# Headache                                               8.487680e-06
# Heart Disease                                                   NaN
# Diabetes                                               1.607804e-03
# Hyper Tension                                                   NaN
# Fatigue                                                         NaN
# Gastrointestinal                                                NaN
# Abroad travel                                          6.454722e-04
# Contact with COVID Patient                             0.000000e+00
# Attended Large Gathering                               2.749716e-31
# Visited Public Exposed Places                          1.822461e-03
# Family working in Public Exposed Places                         NaN
#
#                                          Attended Large Gathering  \
# Breathing Problem                                    5.678590e-15
# Fever                                                1.319902e-02
# Dry Cough                                            2.511514e-03
# Sore throat                                          1.534384e-14
# Running Nose                                         9.942293e-03
# Asthma                                               8.444897e-03
# Chronic Lung Disease                                          NaN
# Headache                                             5.345602e-16
# Heart Disease                                        3.838832e-02
# Diabetes                                             5.811320e-03
# Hyper Tension                                                 NaN
# Fatigue                                                       NaN
# Gastrointestinal                                              NaN
# Abroad travel                                        2.569174e-08
# Contact with COVID Patient                           2.397737e-29
# Attended Large Gathering                             0.000000e+00
# Visited Public Exposed Places                        1.126124e-03
# Family working in Public Exposed Places              2.517613e-03
#
#                                          Visited Public Exposed Places  \
# Breathing Problem                                             0.030614
# Fever                                                              NaN
# Dry Cough                                                     0.033654
# Sore throat                                                   0.013190
# Running Nose                                                       NaN
# Asthma                                                             NaN
# Chronic Lung Disease                                          0.000153
# Headache                                                           NaN
# Heart Disease                                                 0.000012
# Diabetes                                                      0.000221
# Hyper Tension                                                      NaN
# Fatigue                                                            NaN
# Gastrointestinal                                              0.003461
# Abroad travel                                                 0.001500
# Contact with COVID Patient                                    0.001483
# Attended Large Gathering                                      0.000594
# Visited Public Exposed Places                                 0.000000
# Family working in Public Exposed Places                            NaN
#
#                                          Family working in Public Exposed Places
# Breathing Problem                                                            NaN
# Fever                                                                        NaN
# Dry Cough                                                           9.416880e-07
# Sore throat                                                         1.309039e-04
# Running Nose                                                        1.584371e-02
# Asthma                                                              5.214846e-07
# Chronic Lung Disease                                                3.324301e-02
# Headache                                                                     NaN
# Heart Disease                                                                NaN
# Diabetes                                                            1.104834e-05
# Hyper Tension                                                       1.373306e-02
# Fatigue                                                                      NaN
# Gastrointestinal                                                             NaN
# Abroad travel                                                       7.484623e-12
# Contact with COVID Patient                                                   NaN
# Attended Large Gathering                                            3.805064e-03
# Visited Public Exposed Places                                                NaN
# Family working in Public Exposed Places                             0.000000e+00

# %% [markdown]
# Breathing problem has a relation between Fever, Dry Cough ,Sore throat,	Running Nose,	Asthma,	Chronic Lung Disease,	Headache,	Heart Disease,	Diabetes,	Hyper Tension,	Gastrointestinal,	Abroad travel,	Contact with COVID Patient,	Attended Large Gathering,	Visited Public Exposed Places

# %% [markdown]
# # Modeling

# %%
#SVM
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report 

svmClfr=svm.SVC().fit(x,y)
svmPred=svmClfr.predict(xtest)
svmAcc=accuracy_score(ytest,svmPred)
conmat = confusion_matrix(ytest, svmPred)
disp = plot_confusion_matrix(svmClfr, xtest, ytest,cmap=plt.cm.Blues)
disp.ax_.set_title('Confusion Matrix for SVM Classifier')
print("Accuracy of SVM ")
print(classification_report(ytest, svmPred))
print("Class wise Accuracy ")
print("Class 0 ",(conmat[0][0])/(conmat[0][0]+conmat[0][1]))
print("Class 1 ",(conmat[1][1])/(conmat[1][0]+conmat[1][1]))
# Out:
# Accuracy of SVM
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96       210
#            1       0.99      0.99      0.99       877
#
#     accuracy                           0.99      1087
#    macro avg       0.97      0.98      0.98      1087
# weighted avg       0.99      0.99      0.99      1087
#
# Class wise Accuracy
# Class 0  0.9666666666666667
# Class 1  0.9897377423033067

# %%
#RF
from sklearn.ensemble import RandomForestClassifier

rfClfr=RandomForestClassifier().fit(x,y)
rfPred=rfClfr.predict(xtest)
rfAcc=accuracy_score(ytest,rfPred)
conmat = confusion_matrix(ytest, rfPred)
disp = plot_confusion_matrix(rfClfr, xtest, ytest,cmap=plt.cm.Blues)
disp.ax_.set_title('Confusion Matrix for RF Classifier')
print("Accuracy of RF ")
print(classification_report(ytest, rfPred))
print("Class wise Accuracy ")
print("Class 0 ",(conmat[0][0])/(conmat[0][0]+conmat[0][1]))
print("Class 1 ",(conmat[1][1])/(conmat[1][0]+conmat[1][1]))
# Out:
# Accuracy of RF
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       210
#            1       0.99      0.99      0.99       877
#
#     accuracy                           0.98      1087
#    macro avg       0.97      0.98      0.97      1087
# weighted avg       0.98      0.98      0.98      1087
#
# Class wise Accuracy
# Class 0  0.9761904761904762
# Class 1  0.9851767388825542

# %%
#ANN
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense

annx=x.to_numpy()
annxtest=xtest.to_numpy()
anny=y.to_numpy()
annytest=ytest.to_numpy()
model = Sequential()
model.add(Dense(22, input_dim=20, activation='relu'))
model.add(Dense(11, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(annx, anny, epochs=150, batch_size=10)
_, accuracy = model.evaluate(annxtest, annytest)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Epoch 1/150
# 435/435 [==============================] - 0s 881us/step - loss: 0.2694 - accuracy: 0.8730
# Epoch 2/150
# 435/435 [==============================] - 0s 878us/step - loss: 0.1069 - accuracy: 0.9595
# Epoch 3/150
# 435/435 [==============================] - 0s 917us/step - loss: 0.0794 - accuracy: 0.9717
# Epoch 4/150
# 435/435 [==============================] - 0s 883us/step - loss: 0.0680 - accuracy: 0.9763
# Epoch 5/150
# 435/435 [==============================] - 0s 894us/step - loss: 0.0635 - accuracy: 0.9761
# Epoch 6/150
# 435/435 [==============================] - 0s 885us/step - loss: 0.0574 - accuracy: 0.9772
# Epoch 7/150
# 435/435 [==============================] - 0s 906us/step - loss: 0.0551 - accuracy: 0.9775
# Epoch 8/150
# 435/435 [==============================] - 0s 881us/step - loss: 0.0526 - accuracy: 0.9784
# Epoch 9/150
# 435/435 [==============================] - 0s 904us/step - loss: 0.0503 - accuracy: 0.9788
# Epoch 10/150
# 435/435 [==============================] - 0s 887us/step - loss: 0.0500 - accuracy: 0.9768
# Epoch 11/150
# 435/435 [==============================] - 0s 892us/step - loss: 0.0492 - accuracy: 0.9781
# 435/435 [==============================] - 0s 897us/step - loss: 0.0365 - accuracy: 0.9809
# Epoch 135/150
# 435/435 [==============================] - 0s 887us/step - loss: 0.0367 - accuracy: 0.9802
# Epoch 136/150
# 435/435 [==============================] - 0s 933us/step - loss: 0.0363 - accuracy: 0.9786
# Epoch 137/150
# 435/435 [==============================] - 0s 936us/step - loss: 0.0358 - accuracy: 0.9802
# Epoch 138/150
# 435/435 [==============================] - 0s 954us/step - loss: 0.0359 - accuracy: 0.9786
# Epoch 139/150
# 435/435 [==============================] - 0s 945us/step - loss: 0.0360 - accuracy: 0.9811
# Epoch 140/150
# 435/435 [==============================] - 0s 1ms/step - loss: 0.0362 - accuracy: 0.9802
# Epoch 141/150
# 435/435 [==============================] - 0s 1ms/step - loss: 0.0370 - accuracy: 0.9798
# Epoch 142/150
# 435/435 [==============================] - 0s 894us/step - loss: 0.0357 - accuracy: 0.9816
# Epoch 143/150
# 435/435 [==============================] - 0s 897us/step - loss: 0.0354 - accuracy: 0.9795
# Epoch 144/150
# 435/435 [==============================] - 0s 892us/step - loss: 0.0364 - accuracy: 0.9800
# Epoch 145/150
# 435/435 [==============================] - 0s 890us/step - loss: 0.0364 - accuracy: 0.9809
# Epoch 146/150
# 435/435 [==============================] - 0s 883us/step - loss: 0.0367 - accuracy: 0.9795
# Epoch 147/150
# 435/435 [==============================] - 0s 901us/step - loss: 0.0374 - accuracy: 0.9788
# Epoch 148/150
# 435/435 [==============================] - 0s 890us/step - loss: 0.0368 - accuracy: 0.9791
# Epoch 149/150
# 435/435 [==============================] - 0s 929us/step - loss: 0.0360 - accuracy: 0.9807
# Epoch 150/150
# 435/435 [==============================] - 0s 885us/step - loss: 0.0364 - accuracy: 0.9807
# 34/34 [==============================] - 0s 735us/step - loss: 0.0355 - accuracy: 0.9807
# Accuracy: 98.07

# %%
#visualize ann
from ann_visualizer.visualize import ann_viz;

ann_viz(model, view=True, title="My first neural network")

# %%
#XGB
import xgboost as xgb
xgbClfr=xgb.XGBClassifier().fit(x,y)
xgbPred=xgbClfr.predict(xtest)
xgbAcc=accuracy_score(ytest,xgbPred)
conmat = confusion_matrix(ytest, xgbPred)
disp = plot_confusion_matrix(xgbClfr, xtest, ytest,cmap=plt.cm.Blues)
disp.ax_.set_title('Confusion Matrix for XGB Classifier')
print("Accuracy of XGB ")
print(classification_report(ytest, xgbPred))
print("Class wise Accuracy ")
print("Class 0 ",(conmat[0][0])/(conmat[0][0]+conmat[0][1]))
print("Class 1 ",(conmat[1][1])/(conmat[1][0]+conmat[1][1]))
# Out:
# C:\Users\sachi\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:43:21] WARNING: ..\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy of XGB
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       210
#            1       0.99      0.99      0.99       877
#
#     accuracy                           0.98      1087
#    macro avg       0.97      0.98      0.97      1087
# weighted avg       0.98      0.98      0.98      1087
#
# Class wise Accuracy
# Class 0  0.9761904761904762
# Class 1  0.9851767388825542

# %%
xgb.plot_tree(xgbClfr,num_trees=0)
plt.rcParams['figure.figsize'] = [500, 500]
plt.show()

# %%
xgb.plot_importance(xgbClfr)
plt.rcParams['figure.figsize'] = [5, 5]
plt.show()

# %%
#reduce variables based on variable selection
xnew=x[['Sore throat','Dry Cough','Contact with COVID Patient','Hyper Tension','Breathing Problem','Fever','Heart Disease','Visited Public Exposed Places',
      'Diabetes','Asthma','Running Nose','Headache']]
xnewtest=xtest[['Sore throat','Dry Cough','Contact with COVID Patient','Hyper Tension','Breathing Problem','Fever','Heart Disease','Visited Public Exposed Places',
      'Diabetes','Asthma','Running Nose','Headache']]

# %%
xgbClfr=xgb.XGBClassifier().fit(xnew,y)
xgbPred=xgbClfr.predict(xnewtest)
xgbAcc=accuracy_score(ytest,xgbPred)
conmat = confusion_matrix(ytest, xgbPred)
disp = plot_confusion_matrix(xgbClfr, xnewtest, ytest,cmap=plt.cm.Blues)
disp.ax_.set_title('Confusion Matrix for XGB Classifier')
print("Accuracy of XGB ")
print(classification_report(ytest, xgbPred))
print("Class wise Accuracy ")
print("Class 0 ",(conmat[0][0])/(conmat[0][0]+conmat[0][1]))
print("Class 1 ",(conmat[1][1])/(conmat[1][0]+conmat[1][1]))

# %%
from sklearn.decomposition import PCA

datapca=x.iloc[:,0:18]
pca = PCA(n_components=3)
pca_result = pca.fit_transform(datapca[datapca.columns].values)
datapca['pca-one'] = pca_result[:,0]
datapca['pca-two'] = pca_result[:,1] 
datapca['pca-three'] = pca_result[:,2]
print('Explained variation per principal component: {}'.format(pca.explained_variance_ratio_))

# %%
pcaData = pd.DataFrame(data = pca_result
             , columns = ['principal component 1', 'principal component 2','principal component 3'])

# %%
pcadataf=datapca.iloc[:,0:17]
pcadf=pd.DataFrame(data=[[np.corrcoef(pcadataf[c],pca_result[:,n])[1,0] 
               for n in range(pca.n_components_)] for c in pcadataf],
             columns=[1,2,3],
             index = pcadataf.columns)
pcadf

# %%
pca1=[]
pca2=[]
pca3=[]
for i in pcadf.index:
    if abs(pcadf[1][i]) >=0.5:
        pca1.append(i)
    if abs(pcadf[2][i]) >=0.5:
        pca2.append(i)
    if abs(pcadf[3][i]) >=0.5:
        pca3.append(i)

# %%
print('Variables highle correlated with PCA1 are ,')
for j in pca1:
    print(j)

# %%
print('Variables highle correlated with PCA2 are ,')
for j in pca2:
    print(j)

# %%
print('Variables highle correlated with PCA3 are ,')
for j in pca3:
    print(j)

# %%
x['covid']=y
plt.figure(figsize=(16,10))
sns.scatterplot(
    x="pca-one", y="pca-two",
    hue="covid",
    palette=sns.color_palette("tab10", 2),
    data=x,
    legend="full",
    alpha=0.3
)

# %%
ax = plt.figure(figsize=(16,10)).gca(projection='3d')
ax.scatter(
    xs=x.iloc[:]["pca-one"], 
    ys=x.iloc[:]["pca-two"], 
    zs=x.iloc[:]["pca-three"], 
    c=x.iloc[:]["covid"], 
    cmap='tab10'
)
ax.set_xlabel('pca-one')
ax.set_ylabel('pca-two')
ax.set_zlabel('pca-three')
plt.show()

# %% [markdown]
# # Apply Apriori Algorithm to discover assocaition Rules

# %%
from mlxtend.frequent_patterns import apriori

frequent_itemsets_ap = apriori(x.iloc[:,1:20], min_support=0.01, use_colnames=True)

# %%
print(frequent_itemsets_ap)

# %%
frequent_itemsets_ap=frequent_itemsets_ap[frequent_itemsets_ap['support']>0.1]

# %%
from mlxtend.frequent_patterns import association_rules

rules_ap = association_rules(frequent_itemsets_ap, metric="confidence", min_threshold=0.8)
print(rules_ap)

# %%
rules_ap.head()
