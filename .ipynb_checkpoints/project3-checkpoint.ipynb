# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv("Covid Dataset.csv")

# %%
data
# Out:
#         ID Breathing Problem Fever Dry Cough Sore throat Running Nose Asthma  \
# 0        1               Yes   Yes       Yes         Yes          Yes     No
# 1        2               Yes   Yes       Yes         Yes           No    Yes
# 2        3               Yes   Yes       Yes         Yes          Yes    Yes
# 3        4               Yes   Yes       Yes          No           No    Yes
# 4        5               Yes   Yes       Yes         Yes          Yes     No
# ...    ...               ...   ...       ...         ...          ...    ...
# 5429  5430               Yes   Yes        No         Yes          Yes    Yes
# 5430  5431               Yes   Yes       Yes          No          Yes    Yes
# 5431  5432               Yes   Yes       Yes          No           No     No
# 5432  5433               Yes   Yes       Yes          No          Yes     No
# 5433  5434               Yes   Yes       Yes          No          Yes    Yes
#
#      Chronic Lung Disease Headache Heart Disease  ... Fatigue   \
# 0                      No       No            No  ...      Yes
# 1                     Yes      Yes            No  ...      Yes
# 2                     Yes      Yes            No  ...      Yes
# 3                      No       No           Yes  ...       No
# 4                     Yes      Yes           Yes  ...       No
# ...                   ...      ...           ...  ...      ...
# 5429                  Yes       No            No  ...      Yes
# 5430                   No      Yes            No  ...      Yes
# 5431                   No       No           Yes  ...       No
# 5432                   No      Yes           Yes  ...       No
# 5433                   No      Yes            No  ...      Yes
#
#      Gastrointestinal  Abroad travel Contact with COVID Patient  \
# 0                  Yes            No                        Yes
# 1                   No            No                         No
# 2                  Yes           Yes                         No
# 3                   No           Yes                         No
# 4                  Yes            No                        Yes
# ...                ...           ...                        ...
# 5429               Yes            No                         No
# 5430                No            No                         No
# 5431                No            No                         No
# 5432                No            No                         No
# 5433                No            No                         No
#
#      Attended Large Gathering Visited Public Exposed Places  \
# 0                          No                           Yes
# 1                         Yes                           Yes
# 2                          No                            No
# 3                         Yes                           Yes
# 4                          No                           Yes
# ...                       ...                           ...
# 5429                       No                            No
# 5430                       No                            No
# 5431                       No                            No
# 5432                       No                            No
# 5433                       No                            No
#
#      Family working in Public Exposed Places Wearing Masks  \
# 0                                        Yes            No
# 1                                         No            No
# 2                                         No            No
# 3                                         No            No
# 4                                         No            No
# ...                                      ...           ...
# 5429                                      No            No
# 5430                                      No            No
# 5431                                      No            No
# 5432                                      No            No
# 5433                                      No            No
#
#      Sanitization from Market COVID-19
# 0                          No      Yes
# 1                          No      Yes
# 2                          No      Yes
# 3                          No      Yes
# 4                          No      Yes
# ...                       ...      ...
# 5429                       No      Yes
# 5430                       No      Yes
# 5431                       No       No
# 5432                       No       No
# 5433                       No       No
#
# [5434 rows x 22 columns]

# %%
#check for missing values
data.isna().sum()
# Out:
# ID                                         0
# Breathing Problem                          0
# Fever                                      0
# Dry Cough                                  0
# Sore throat                                0
# Running Nose                               0
# Asthma                                     0
# Chronic Lung Disease                       0
# Headache                                   0
# Heart Disease                              0
# Diabetes                                   0
# Hyper Tension                              0
# Fatigue                                    0
# Gastrointestinal                           0
# Abroad travel                              0
# Contact with COVID Patient                 0
# Attended Large Gathering                   0
# Visited Public Exposed Places              0
# Family working in Public Exposed Places    0
# Wearing Masks                              0
# Sanitization from Market                   0
# COVID-19                                   0
# dtype: int64

# %%
#separte the Features and Target variable
X=data.iloc[:,0:21]
Y=data.iloc[:,21:22]

# %%
#split the dataset into train and test sets
x,xtest,y,ytest=train_test_split(X,Y,train_size=0.8)

# %% [markdown]
# # Exploratory Analysis

# %%
def barPerc(df,xVar,ax):
    '''
    barPerc(): Add percentage for hues to bar plots
    args:
        df: pandas dataframe
        xVar: (string) X variable 
        ax: Axes object (for Seaborn Countplot/Bar plot or
                         pandas bar plot)
    '''
    # 1. how many X categories
    ##   check for NaN and remove
    numX=len([x for x in df[xVar].unique() if x==x])

    # 2. The bars are created in hue order, organize them
    bars = ax.patches
    ## 2a. For each X variable
    for ind in range(numX):
        ## 2b. Get every hue bar
        ##     ex. 8 X categories, 4 hues =>
        ##    [0, 8, 16, 24] are hue bars for 1st X category
        hueBars=bars[ind:][::numX]
        ## 2c. Get the total height (for percentages)
        total = sum([x.get_height() for x in hueBars])

        # 3. Print the percentage on the bars
        for bar in hueBars:
            ax.text(bar.get_x() + bar.get_width()/2.,
                    bar.get_height(),
                    f'{bar.get_height()/total:.0%}',
                    ha="center",va="bottom")

# %%
sns.countplot(x='COVID-19',data=data)
# Out:
# <AxesSubplot:xlabel='COVID-19', ylabel='count'>

# %%
data['COVID-19'].value_counts()
# Out:
# Yes    4383
# No     1051
# Name: COVID-19, dtype: int64

# %%
x.columns
# Out:
# Index(['ID', 'Breathing Problem', 'Fever', 'Dry Cough', 'Sore throat',
#        'Running Nose', 'Asthma', 'Chronic Lung Disease', 'Headache',
#        'Heart Disease', 'Diabetes', 'Hyper Tension', 'Fatigue ',
#        'Gastrointestinal ', 'Abroad travel', 'Contact with COVID Patient',
#        'Attended Large Gathering', 'Visited Public Exposed Places',
#        'Family working in Public Exposed Places', 'Wearing Masks',
#        'Sanitization from Market'],
#       dtype='object')

# %%
#plt.rcParams.update({'figure.figsize':(7.5,5), 'figure.dpi':100})  
fig, axs = plt.subplots(1, 5, figsize=(21, 4))
sns.countplot(ax=axs[0],x='Breathing Problem',hue='Dry Cough',data=x)
barPerc(x,'Breathing Problem',axs[0])
sns.countplot(ax=axs[1],x='Breathing Problem',hue='Sore throat',data=x)
barPerc(x,'Breathing Problem',axs[1])
sns.countplot(ax=axs[2],x='Breathing Problem',hue='Running Nose',data=x)
barPerc(x,'Breathing Problem',axs[2])
sns.countplot(ax=axs[3],x='Breathing Problem',hue='Asthma',data=x)
barPerc(x,'Breathing Problem',axs[3])
sns.countplot(ax=axs[4],x='Breathing Problem',hue='Chronic Lung Disease',data=x)
barPerc(x,'Breathing Problem',axs[4])

# %%
fig, axs = plt.subplots(3, 2, figsize=(17, 14))
sns.countplot(ax=axs[0][0],x='Chronic Lung Disease',hue='Dry Cough',data=x)
barPerc(x,'Chronic Lung Disease',axs[0][0])

sns.countplot(ax=axs[0][1],x='Chronic Lung Disease',hue='Breathing Problem',data=x)
barPerc(x,'Chronic Lung Disease',axs[0][1])

sns.countplot(ax=axs[1][0],x='Chronic Lung Disease',hue='Fever',data=x)
barPerc(x,'Chronic Lung Disease',axs[1][0])

sns.countplot(ax=axs[1][1],x='Chronic Lung Disease',hue='Sore throat',data=x)
barPerc(x,'Chronic Lung Disease',axs[1][1])

sns.countplot(ax=axs[2][0],x='Chronic Lung Disease',hue='Fatigue ',data=x)
barPerc(x,'Chronic Lung Disease',axs[2][0])

sns.countplot(ax=axs[2][1],x='Chronic Lung Disease',hue='Running Nose',data=x)
barPerc(x,'Chronic Lung Disease',axs[2][1])

# %%
fig, axs = plt.subplots(3, 2, figsize=(15, 15))
sns.countplot(ax=axs[0][0],x='Asthma',hue='Dry Cough',data=x)
barPerc(x,'Asthma',axs[0][0])

sns.countplot(ax=axs[0][1],x='Asthma',hue='Breathing Problem',data=x)
barPerc(x,'Asthma',axs[0][1])

sns.countplot(ax=axs[1][0],x='Asthma',hue='Fever',data=x)
barPerc(x,'Asthma',axs[1][0])

sns.countplot(ax=axs[1][1],x='Asthma',hue='Sore throat',data=x)
barPerc(x,'Asthma',axs[1][1])

sns.countplot(ax=axs[2][0],x='Asthma',hue='Fatigue ',data=x)
barPerc(x,'Asthma',axs[2][0])

sns.countplot(ax=axs[2][1],x='Asthma',hue='Running Nose',data=x)
barPerc(x,'Asthma',axs[2][1])

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5))
sns.countplot(ax=axs[0],x='Fever',hue='Headache',data=x)
barPerc(x,'Fever',axs[0])
sns.countplot(ax=axs[1],x='Chronic Lung Disease',hue='Fever',data=x)
barPerc(x,'Chronic Lung Disease',axs[1])

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 5))
sns.countplot(ax=axs[0],x='Heart Disease',hue='Hyper Tension',data=x)
barPerc(x,'Heart Disease',axs[0])
sns.countplot(ax=axs[1],x='Heart Disease',hue='Fever',data=x)
barPerc(x,'Heart Disease',axs[1])

sns.countplot(ax=axs[2],x='Heart Disease',hue='Fatigue ',data=x)
barPerc(x,'Heart Disease',axs[2])

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 5))
sns.countplot(ax=axs[0],x='Abroad travel',hue='Attended Large Gathering',data=x)
barPerc(x,'Abroad travel',axs[0])
sns.countplot(ax=axs[1],x='Abroad travel',hue='Visited Public Exposed Places',data=x)
barPerc(x,'Abroad travel',axs[1])
sns.countplot(ax=axs[2],x='Abroad travel',hue='Family working in Public Exposed Places',data=x)
barPerc(x,'Abroad travel',axs[2])
plt.legend(loc='upper right', title='Family working in Public\n Exposed Places')

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 5))
sns.countplot(ax=axs[0],x='Contact with COVID Patient',hue='Attended Large Gathering',data=x)
barPerc(x,'Contact with COVID Patient',axs[0])
sns.countplot(ax=axs[1],x='Contact with COVID Patient',hue='Visited Public Exposed Places',data=x)
barPerc(x,'Contact with COVID Patient',axs[1])
sns.countplot(ax=axs[2],x='Contact with COVID Patient',hue='Family working in Public Exposed Places',data=x)
barPerc(x,'Contact with COVID Patient',axs[2])
plt.legend(loc='upper left', title='Family working in Public\n Exposed Places')

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
sns.countplot(ax=axs[0],x='Contact with COVID Patient',hue='Wearing Masks',data=x)
sns.countplot(ax=axs[1],x='Contact with COVID Patient',hue='Sanitization from Market',data=x)
# Out:
# <AxesSubplot:xlabel='Contact with COVID Patient', ylabel='count'>

# %%
#combine x and y for further analysis
x['covid']=y
# Out:
# <ipython-input-416-5ebeeb27d164>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['covid']=y

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 5))
sns.countplot(ax=axs[0],x='covid',hue='Breathing Problem',data=x)
barPerc(x,'covid',axs[0])
sns.countplot(ax=axs[1],x='covid',hue='Asthma',data=x) 
barPerc(x,'covid',axs[1])
sns.countplot(ax=axs[2],x='covid',hue='Headache',data=x)
barPerc(x,'covid',axs[2])

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
temp=x[x['covid']=='Yes']
sns.countplot(ax=axs[0],x='Chronic Lung Disease',hue='Breathing Problem',data=temp)
axs[0].title.set_text('COVID Positive')
barPerc(x,'Chronic Lung Disease',axs[0])
temp=x[x['covid']=='No']
sns.countplot(ax=axs[1],x='Chronic Lung Disease',hue='Breathing Problem',data=temp)
axs[1].title.set_text('COVID Negative')
barPerc(x,'Chronic Lung Disease',axs[1])

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
temp=x[x['covid']=='Yes']
sns.countplot(ax=axs[0],x='Chronic Lung Disease',hue='Asthma',data=temp)
axs[0].title.set_text('COVID Positive')
barPerc(x,'Chronic Lung Disease',axs[0])

temp=x[x['covid']=='No']
sns.countplot(ax=axs[1],x='Chronic Lung Disease',hue='Asthma',data=temp)
axs[1].title.set_text('COVID Negative')
barPerc(x,'Chronic Lung Disease',axs[1])

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
temp=x[x['covid']=='Yes']
sns.countplot(ax=axs[0],x='Chronic Lung Disease',hue='Dry Cough',data=temp)
axs[0].title.set_text('COVID Positive')
barPerc(x,'Chronic Lung Disease',axs[0])

temp=x[x['covid']=='No']
sns.countplot(ax=axs[1],x='Chronic Lung Disease',hue='Dry Cough',data=temp)
axs[1].title.set_text('COVID Negative')
barPerc(x,'Chronic Lung Disease',axs[1])

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
temp=x[x['covid']=='Yes']
sns.countplot(ax=axs[0],x='Heart Disease',hue='Breathing Problem',data=temp)
barPerc(x,'Heart Disease',axs[0])

axs[0].title.set_text('COVID Positive')
temp=x[x['covid']=='No']
sns.countplot(ax=axs[1],x='Heart Disease',hue='Breathing Problem',data=temp)
axs[1].title.set_text('COVID Negative')
barPerc(x,'Heart Disease',axs[1])

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
temp=x[x['covid']=='Yes']
sns.countplot(ax=axs[0],x='Heart Disease',hue='Asthma',data=temp)
axs[0].title.set_text('COVID Positive')
barPerc(x,'Heart Disease',axs[0])

temp=x[x['covid']=='No']
sns.countplot(ax=axs[1],x='Heart Disease',hue='Asthma',data=temp)
axs[1].title.set_text('COVID Negative')
barPerc(x,'Heart Disease',axs[1])

# %%
#meaningless
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
temp=x[x['covid']=='Yes']
sns.countplot(ax=axs[0],x='Attended Large Gathering',hue='Wearing Masks',data=temp)
axs[0].title.set_text('COVID Positive')
temp=x[x['covid']=='No']
sns.countplot(ax=axs[1],x='Attended Large Gathering',hue='Wearing Masks',data=temp)
axs[1].title.set_text('COVID Negative')

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
temp=x[x['covid']=='Yes']
sns.countplot(ax=axs[0],x='Attended Large Gathering',hue='Visited Public Exposed Places',data=temp)
axs[0].title.set_text('COVID Positive')
barPerc(x,'Attended Large Gathering',axs[0])

temp=x[x['covid']=='No']
sns.countplot(ax=axs[1],x='Attended Large Gathering',hue='Visited Public Exposed Places',data=temp)
axs[1].title.set_text('COVID Negative')
barPerc(x,'Attended Large Gathering',axs[1])

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
temp=x[x['covid']=='Yes']
sns.countplot(ax=axs[0],x='Attended Large Gathering',hue='Family working in Public Exposed Places',data=temp)
axs[0].title.set_text('COVID Positive')
barPerc(x,'Attended Large Gathering',axs[0])

temp=x[x['covid']=='No']
sns.countplot(ax=axs[1],x='Attended Large Gathering',hue='Family working in Public Exposed Places',data=temp)
axs[1].title.set_text('COVID Negative')
barPerc(x,'Attended Large Gathering',axs[1])

# %%
fig, axs = plt.subplots(1, 1, figsize=(20, 5))
sns.countplot(x='covid',hue='Contact with COVID Patient',data=x)
barPerc(x,'covid',axs)
#can observe the airborn nature

# %%
fig, axs = plt.subplots(1, 1, figsize=(20, 5))
sns.countplot(x='covid',hue='Abroad travel',data=x)
# Out:
# <AxesSubplot:xlabel='covid', ylabel='count'>

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
temp=x[x['covid']=='Yes']
sns.countplot(ax=axs[0],x='Abroad travel',hue='Attended Large Gathering',data=temp)
axs[0].title.set_text('COVID Positive')
barPerc(x,'Abroad travel',axs[0])

temp=x[x['covid']=='No']
sns.countplot(ax=axs[1],x='Abroad travel',hue='Attended Large Gathering',data=temp)
axs[1].title.set_text('COVID Negative')

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
temp=x[x['covid']=='Yes']
sns.countplot(ax=axs[0],x='Abroad travel',hue='Visited Public Exposed Places',data=temp)
axs[0].title.set_text('COVID Positive')
barPerc(x,'Abroad travel',axs[0])

temp=x[x['covid']=='No']
sns.countplot(ax=axs[1],x='Abroad travel',hue='Visited Public Exposed Places',data=temp)
axs[1].title.set_text('COVID Negative')

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 5))
sns.countplot(ax=axs[0],hue='covid',x='Visited Public Exposed Places',data=x)
barPerc(x,'Visited Public Exposed Places',axs[0])

sns.countplot(ax=axs[1],hue='covid',x='Attended Large Gathering',data=x)
barPerc(x,'Attended Large Gathering',axs[1])


sns.countplot(ax=axs[2],hue='Contact with COVID Patient',x='Attended Large Gathering',data=x)
barPerc(x,'Attended Large Gathering',axs[1])

# %%
temp=x[x['covid']=='Yes']

fig, axs = plt.subplots(1, 3, figsize=(20, 5))
sns.countplot(ax=axs[0],hue='Visited Public Exposed Places',x='Contact with COVID Patient',data=temp)
barPerc(x,'Contact with COVID Patient',axs[0])

sns.countplot(ax=axs[1],hue='Abroad travel',x='Contact with COVID Patient',data=temp)
barPerc(x,'Contact with COVID Patient',axs[1])


sns.countplot(ax=axs[2],hue='Family working in Public Exposed Places',x='Contact with COVID Patient',data=temp)
barPerc(x,'Contact with COVID Patient',axs[2])

# %% [markdown]
# # New

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 5))
sns.countplot(ax=axs[0],x='Asthma',data=temp)

sns.countplot(ax=axs[1],x='Breathing Problem',data=temp)

sns.countplot(ax=axs[2],x='Hyper Tension',data=temp)
# Out:
# <AxesSubplot:xlabel='Hyper Tension', ylabel='count'>

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 5))
sns.countplot(ax=axs[0],x='Breathing Problem',data=temp)

sns.countplot(ax=axs[1],x='Sore throat',data=temp)

sns.countplot(ax=axs[2],x='Running Nose',data=temp)
# Out:
# <AxesSubplot:xlabel='Running Nose', ylabel='count'>

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 5))
sns.countplot(ax=axs[0],x='covid',hue='Breathing Problem',data=x)
barPerc(x,'covid',axs[0])

sns.countplot(ax=axs[1],x='covid',hue='Sore throat',data=x)
barPerc(x,'covid',axs[1])

sns.countplot(ax=axs[2],x='covid',hue='Running Nose',data=x)
barPerc(x,'covid',axs[2])

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 5))
sns.countplot(ax=axs[0],x='Headache',data=temp)

sns.countplot(ax=axs[1],x='Fever',data=temp)

sns.countplot(ax=axs[2],x='Fatigue ',data=temp)
# Out:
# <AxesSubplot:xlabel='Fatigue ', ylabel='count'>

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 5))
sns.countplot(ax=axs[0],x='covid',hue='Headache',data=x)
barPerc(x,'covid',axs[0])

sns.countplot(ax=axs[1],x='covid',hue='Fever',data=x)
barPerc(x,'covid',axs[0])

sns.countplot(ax=axs[2],x='covid',hue='Fatigue ',data=x)
barPerc(x,'covid',axs[0])

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 5))
sns.countplot(ax=axs[0],x='Contact with COVID Patient',data=temp)

sns.countplot(ax=axs[1],x='Abroad travel',data=temp)

sns.countplot(ax=axs[2],x='Attended Large Gathering',data=temp)
# Out:
# <AxesSubplot:xlabel='Attended Large Gathering', ylabel='count'>

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 5))
sns.countplot(ax=axs[0],x='covid', hue='Contact with COVID Patient',data=x)
barPerc(x,'covid',axs[0])

sns.countplot(ax=axs[1],x='covid', hue='Abroad travel',data=x)
barPerc(x,'covid',axs[1])

sns.countplot(ax=axs[2],x='covid', hue='Attended Large Gathering',data=x)
barPerc(x,'covid',axs[2])
# Out:
# posx and posy should be finite values
# posx and posy should be finite values

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
sns.countplot(ax=axs[0],x='Visited Public Exposed Places',data=temp)

sns.countplot(ax=axs[1],x='Family working in Public Exposed Places',data=temp)
# Out:
# <AxesSubplot:xlabel='Family working in Public Exposed Places', ylabel='count'>

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
sns.countplot(ax=axs[0],x='covid',hue='Visited Public Exposed Places',data=x)
barPerc(x,'covid',axs[0])

sns.countplot(ax=axs[1],x='covid',hue='Family working in Public Exposed Places',data=x)
barPerc(x,'covid',axs[1])

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
sns.countplot(ax=axs[0],x='covid',hue='Wearing Masks',data=x)

sns.countplot(ax=axs[1],x='covid',hue='Sanitization from Market',data=x)
# Out:
# <AxesSubplot:xlabel='covid', ylabel='count'>

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
sns.countplot(ax=axs[0],x='Wearing Masks',data=temp)
barPerc(x,'covid',axs[0])

sns.countplot(ax=axs[1],x='Sanitization from Market',data=temp)
barPerc(x,'covid',axs[1])

# %%
def without_hue(plot, feature):
    total = len(feature)
    for p in plot.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() / 2 - 0.05
        y = p.get_y() + p.get_height()
        ax.annotate(percentage, (x, y), size = 12)
    plt.show()

# %%
temp=x[x['covid']=='Yes']

fig, axs = plt.subplots(1, 5, figsize=(20, 5))
sns.countplot(ax=axs[0],x='Fever',data=temp)

sns.countplot(ax=axs[1],x='Headache',data=temp)

sns.countplot(ax=axs[2],x='Sore throat',data=temp)

sns.countplot(ax=axs[3],x='Dry Cough',data=temp)

sns.countplot(ax=axs[4],x='Fatigue ',data=temp)
# Out:
# <AxesSubplot:xlabel='Fatigue ', ylabel='count'>

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
sns.countplot(ax=axs[0],x='covid',hue='Asthma',data=x)
barPerc(x,'covid',axs[0])

sns.countplot(ax=axs[1],x='covid',hue='Chronic Lung Disease',data=x)
barPerc(x,'covid',axs[1])

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
sns.countplot(ax=axs[0],x='Asthma',data=temp)

sns.countplot(ax=axs[1],x='Chronic Lung Disease',data=temp)
# Out:
# <AxesSubplot:xlabel='Chronic Lung Disease', ylabel='count'>

# %%
fig, axs = plt.subplots(1, 5, figsize=(20, 5))
sns.countplot(ax=axs[0],x='covid',hue='Heart Disease',data=x)   
barPerc(x,'covid',axs[0])

sns.countplot(ax=axs[1],x='covid',hue='Diabetes',data=x)
barPerc(x,'covid',axs[1])

sns.countplot(ax=axs[2],x='covid',hue='Hyper Tension',data=x)
barPerc(x,'covid',axs[2])

sns.countplot(ax=axs[3],x='covid',hue='Gastrointestinal ',data=x)
barPerc(x,'covid',axs[3])

sns.countplot(ax=axs[4],x='covid',hue='Chronic Lung Disease',data=x)
barPerc(x,'covid',axs[4])

# %%
fig, axs = plt.subplots(1, 4, figsize=(20, 5))
sns.countplot(ax=axs[0],x='Heart Disease',data=temp)   

sns.countplot(ax=axs[1],x='Diabetes',data=temp)

sns.countplot(ax=axs[2],x='Hyper Tension',data=temp)

sns.countplot(ax=axs[3],x='Gastrointestinal ',data=temp)
# Out:
# <AxesSubplot:xlabel='Gastrointestinal ', ylabel='count'>

# %% [markdown]
# # chi square tests to evalute the correlation
#
# Let H0: There is no Relationship between two variables (Two variables are independent)
#
#     H1: There is a Relationship between two variables (Two variables are not independent)

# %%
#encode values
dic={'Yes':1,'No':0}
for i in x.columns:
    x[i].replace(dic,inplace=True)
for i in xtest.columns:
    xtest[i].replace(dic,inplace=True)
for i in ytest:
    ytest[i].replace(dic,inplace=True)
# Out:
# C:\Users\sachi\anaconda3\lib\site-packages\pandas\core\series.py:4509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
#remove covid and ID from datafram
y=x['covid']
x.drop(['covid'],inplace=True,axis=1)
x.drop(['ID'],inplace=True,axis=1)
xtest.drop(['ID'],inplace=True,axis=1)
# Out:
# C:\Users\sachi\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
from scipy.stats import chi2_contingency
colnames=x.columns
for i in colnames:
    contingency=pd.crosstab(x[i],y)
    print('Contingency table for Covid and ',i)
    print(contingency)
    stat,p,dof,expected=chi2_contingency(contingency)
    alpha=0.05
    if p<= alpha:
        print('Covid and ',i,' are related')
        
    else:
        print('Covid and ',i,' are not  related')
    print("########################################3")
# Out:
# Contingency table for Covid and  Breathing Problem
# covid                0     1
# Breathing Problem
# 0                  632   813
# 1                  200  2702
# Covid and  Breathing Problem  are related
# ########################################3
# Contingency table for Covid and  Fever
# covid    0     1
# Fever
# 0      423   513
# 1      409  3002
# Covid and  Fever  are related
# ########################################3
# Contingency table for Covid and  Dry Cough
# covid        0     1
# Dry Cough
# 0          501   412
# 1          331  3103
# Covid and  Dry Cough  are related
# ########################################3
# Contingency table for Covid and  Sore throat
# covid          0     1
# Sore throat
# 0            610   581
# 1            222  2934
# Covid and  Sore throat  are related
# ########################################3
# Contingency table for Covid and  Running Nose
# covid           0     1
# Running Nose
# 0             357  1605
# 1             475  1910
# Covid and  Running Nose  are not  related
# ########################################3
# Contingency table for Covid and  Asthma
# covid     0     1
# Asthma
# 0       525  1805
# 1       307  1710
# Covid and  Asthma  are related
# ########################################3
# Contingency table for Covid and  Chronic Lung Disease
# covid                   0     1
# Chronic Lung Disease
# 0                     400  1901
# 1                     432  1614
# Covid and  Chronic Lung Disease  are related
# ########################################3
# Contingency table for Covid and  Headache
# covid       0     1
# Headache
# 0         385  1761
# 1         447  1754
# Covid and  Headache  are not  related
# ########################################3
# Contingency table for Covid and  Heart Disease
# covid            0     1
# Heart Disease
# 0              469  1863
# 1              363  1652
# Covid and  Heart Disease  are not  related
# ########################################3
# Contingency table for Covid and  Diabetes
# covid       0     1
# Diabetes
# 0         467  1818
# 1         365  1697
# Covid and  Diabetes  are related
# ########################################3
# Contingency table for Covid and  Hyper Tension
# covid            0     1
# Hyper Tension
# 0              506  1714
# 1              326  1801
# Covid and  Hyper Tension  are related
# ########################################3
# Contingency table for Covid and  Fatigue
# covid       0     1
# Fatigue
# 0         363  1736
# 1         469  1779
# Covid and  Fatigue   are related
# ########################################3
# Contingency table for Covid and  Gastrointestinal
# covid                0     1
# Gastrointestinal
# 0                  443  1872
# 1                  389  1643
# Covid and  Gastrointestinal   are not  related
# ########################################3
# Contingency table for Covid and  Abroad travel
# covid            0     1
# Abroad travel
# 0              832  1557
# 1                0  1958
# Covid and  Abroad travel  are related
# ########################################3
# Contingency table for Covid and  Contact with COVID Patient
# covid                         0     1
# Contact with COVID Patient
# 0                           712  1427
# 1                           120  2088
# Covid and  Contact with COVID Patient  are related
# ########################################3
# Contingency table for Covid and  Attended Large Gathering
# covid                       0     1
# Attended Large Gathering
# 0                         778  1540
# 1                          54  1975
# Covid and  Attended Large Gathering  are related
# ########################################3
# Contingency table for Covid and  Visited Public Exposed Places
# covid                            0     1
# Visited Public Exposed Places
# 0                              509  1575
# 1                              323  1940
# Covid and  Visited Public Exposed Places  are related
# ########################################3
# Contingency table for Covid and  Family working in Public Exposed Places
# covid                                      0     1
# Family working in Public Exposed Places
# 0                                        617  1906
# 1                                        215  1609
# Covid and  Family working in Public Exposed Places  are related
# ########################################3
# Contingency table for Covid and  Wearing Masks
# covid            0     1
# Wearing Masks
# 0              832  3515
# Covid and  Wearing Masks  are not  related
# ########################################3
# Contingency table for Covid and  Sanitization from Market
# covid                       0     1
# Sanitization from Market
# 0                         832  3515
# Covid and  Sanitization from Market  are not  related
# ########################################3

# %%
from sklearn.feature_selection import chi2

xtemp=x.iloc[:,0:18]
resultant = pd.DataFrame(data=[(0 for i in range(len(xtemp.columns))) for i in range(len(xtemp.columns))], 
                         columns=list(xtemp.columns))
resultant.set_index(pd.Index(list(xtemp.columns)), inplace = True)

# %%
import numpy as np

for i in list(xtemp.columns):
    for j in list(xtemp.columns):
        if i != j:
            chi2_val, p_val = chi2(np.array(xtemp[i]).reshape(-1, 1), np.array(xtemp[j]).reshape(-1, 1))
            resultant.loc[i,j] = p_val
print(resultant)
# Out:
#                                          Breathing Problem         Fever  \
# Breathing Problem                             0.000000e+00  1.173199e-03
# Fever                                         9.003334e-03  0.000000e+00
# Dry Cough                                     1.899652e-06  3.063971e-05
# Sore throat                                   4.047826e-24  2.943253e-28
# Running Nose                                  6.279573e-02  2.171758e-03
# Asthma                                        9.682207e-05  7.384060e-04
# Chronic Lung Disease                          1.997591e-05  4.058855e-01
# Headache                                      1.225020e-02  6.890420e-02
# Heart Disease                                 1.016381e-04  2.100302e-01
# Diabetes                                      1.170436e-03  2.126172e-02
# Hyper Tension                                 9.711944e-02  6.077512e-04
# Fatigue                                       6.629328e-01  7.674577e-03
# Gastrointestinal                              8.947469e-04  3.458161e-01
# Abroad travel                                 6.145395e-08  4.607149e-09
# Contact with COVID Patient                    7.142971e-25  5.096934e-14
# Attended Large Gathering                      2.214426e-21  5.596419e-04
# Visited Public Exposed Places                 1.719406e-03  8.671393e-01
# Abroad travel                                          1.933509e-04
# Contact with COVID Patient                             0.000000e+00
# Attended Large Gathering                               1.107352e-33
# Visited Public Exposed Places                          1.723095e-03
# Family working in Public Exposed Places                8.689138e-01
#
#                                          Attended Large Gathering  \
# Breathing Problem                                    6.565616e-14
# Fever                                                2.833687e-02
# Dry Cough                                            1.086845e-04
# Sore throat                                          4.493792e-13
# Running Nose                                         1.771443e-02
# Asthma                                               4.249997e-02
# Chronic Lung Disease                                 4.515612e-01
# Headache                                             1.797597e-13
# Heart Disease                                        3.437553e-03
# Diabetes                                             3.860426e-03
# Hyper Tension                                        8.689683e-01
# Fatigue                                              7.391247e-02
# Gastrointestinal                                     2.577072e-01
# Abroad travel                                        3.195792e-08
# Contact with COVID Patient                           3.273355e-31
# Attended Large Gathering                             0.000000e+00
# Visited Public Exposed Places                        1.564354e-04
# Family working in Public Exposed Places              2.067766e-03
#
#                                          Visited Public Exposed Places  \
# Breathing Problem                                             0.009044
# Fever                                                         0.910731
# Dry Cough                                                     0.006755
# Sore throat                                                   0.002450
# Running Nose                                                  0.125336
# Asthma                                                        0.349925
# Chronic Lung Disease                                          0.000001
# Headache                                                      0.791902
# Heart Disease                                                 0.000104
# Diabetes                                                      0.000461
# Hyper Tension                                                 0.264523
# Fatigue                                                       0.518760
# Gastrointestinal                                              0.000890
# Abroad travel                                                 0.000441
# Contact with COVID Patient                                    0.001497
# Attended Large Gathering                                      0.000067
# Visited Public Exposed Places                                 0.000000
# Family working in Public Exposed Places                       0.106431
#
#                                          Family working in Public Exposed Places
# Breathing Problem                                                   4.907094e-01
# Fever                                                               8.149574e-01
# Dry Cough                                                           8.943939e-07
# Sore throat                                                         5.533802e-04
# Running Nose                                                        1.478848e-02
# Asthma                                                              9.339544e-08
# Chronic Lung Disease                                                4.152032e-02
# Headache                                                            9.814266e-01
# Heart Disease                                                       5.500558e-02
# Diabetes                                                            7.663318e-07
# Hyper Tension                                                       4.099389e-02
# Fatigue                                                             6.303428e-01
# Gastrointestinal                                                    3.538096e-01
# Abroad travel                                                       1.530022e-12
# Contact with COVID Patient                                          8.792179e-01
# Attended Large Gathering                                            3.151818e-03
# Visited Public Exposed Places                                       1.423000e-01
# Family working in Public Exposed Places                             0.000000e+00

# %%
fig = plt.figure(figsize=(20,20))
sns.heatmap(resultant, annot=True, cmap='Blues')
plt.title('Chi-Square Test Results')
plt.show()

# %%
resultant[resultant<0.05]
# Out:
#                                          Breathing Problem         Fever  \
# Breathing Problem                             0.000000e+00  1.173199e-03
# Fever                                         9.003334e-03  0.000000e+00
# Dry Cough                                     1.899652e-06  3.063971e-05
# Sore throat                                   4.047826e-24  2.943253e-28
# Running Nose                                           NaN  2.171758e-03
# Asthma                                        9.682207e-05  7.384060e-04
# Chronic Lung Disease                          1.997591e-05           NaN
# Headache                                      1.225020e-02           NaN
# Heart Disease                                 1.016381e-04           NaN
# Diabetes                                      1.170436e-03  2.126172e-02
# Hyper Tension                                          NaN  6.077512e-04
# Fatigue                                                NaN  7.674577e-03
# Gastrointestinal                              8.947469e-04           NaN
# Abroad travel                                 6.145395e-08  4.607149e-09
# Contact with COVID Patient                    7.142971e-25  5.096934e-14
# Attended Large Gathering                      2.214426e-21  5.596419e-04
# Visited Public Exposed Places                 1.719406e-03           NaN
# Family working in Public Exposed Places                NaN           NaN
#
#                                             Dry Cough   Sore throat  \
# Breathing Problem                        2.058425e-09  6.506233e-29
# Fever                                    2.433935e-05  1.478720e-22
# Dry Cough                                0.000000e+00  1.714200e-11
# Sore throat                              1.531042e-14  0.000000e+00
# Running Nose                                      NaN           NaN
# Asthma                                   4.840947e-06  1.306166e-04
# Chronic Lung Disease                     2.506399e-02  4.504653e-02
# Headache                                          NaN           NaN
# Heart Disease                            3.663929e-02           NaN
# Diabetes                                          NaN           NaN
# Hyper Tension                            2.055965e-04           NaN
# Fatigue                                           NaN           NaN
# Gastrointestinal                                  NaN           NaN
# Abroad travel                            1.630140e-59  2.406606e-23
# Contact with COVID Patient               7.205756e-09  3.355173e-20
# Attended Large Gathering                 6.962090e-10  5.517091e-24
# Visited Public Exposed Places            4.270318e-05  6.141839e-05
# Family working in Public Exposed Places  3.133790e-16  4.996505e-07
#
#                                          Running Nose        Asthma  \
# Breathing Problem                                 NaN  2.140269e-03
# Fever                                        0.034221  3.243128e-02
# Dry Cough                                         NaN  4.213910e-03
# Sore throat                                       NaN  6.239782e-03
# Running Nose                                 0.000000           NaN
# Asthma                                            NaN  0.000000e+00
# Chronic Lung Disease                              NaN           NaN
# Headache                                     0.001664           NaN
# Heart Disease                                0.010000  4.898345e-04
# Diabetes                                     0.048037           NaN
# Hyper Tension                                     NaN           NaN
# Fatigue                                           NaN           NaN
# Gastrointestinal                                  NaN  1.200190e-06
# Abroad travel                                     NaN  2.999169e-03
# Contact with COVID Patient                        NaN           NaN
# Attended Large Gathering                     0.009945  4.303600e-02
# Visited Public Exposed Places                     NaN           NaN
# Family working in Public Exposed Places      0.005708  2.762566e-08
#
#                                          Chronic Lung Disease      Headache  \
# Breathing Problem                                    0.000725  3.983806e-02
# Fever                                                     NaN           NaN
# Dry Cough                                                 NaN           NaN
# Sore throat                                               NaN           NaN
# Running Nose                                              NaN  2.641148e-03
# Asthma                                                    NaN           NaN
# Chronic Lung Disease                                 0.000000  1.511718e-02
# Headache                                             0.018961  0.000000e+00
# Heart Disease                                             NaN  5.171621e-03
# Diabetes                                             0.023130           NaN
# Hyper Tension                                             NaN  8.578447e-20
# Fatigue                                              0.008727  2.328663e-02
# Gastrointestinal                                     0.017628  3.817768e-06
# Abroad travel                                        0.000041  2.492106e-02
# Contact with COVID Patient                           0.011547  1.170718e-05
# Attended Large Gathering                                  NaN  1.972155e-14
# Visited Public Exposed Places                        0.000004           NaN
# Family working in Public Exposed Places              0.032813           NaN
#
#                                          Heart Disease      Diabetes  \
# Breathing Problem                             0.002217  9.843020e-03
# Fever                                              NaN           NaN
# Dry Cough                                          NaN           NaN
# Sore throat                                        NaN           NaN
# Running Nose                                  0.018144           NaN
# Asthma                                        0.000493           NaN
# Chronic Lung Disease                               NaN  2.265441e-02
# Headache                                      0.007311           NaN
# Heart Disease                                 0.000000           NaN
# Diabetes                                           NaN  0.000000e+00
# Hyper Tension                                 0.018755  2.379171e-02
# Fatigue                                       0.004009           NaN
# Gastrointestinal                                   NaN  4.501227e-02
# Abroad travel                                      NaN           NaN
# Contact with COVID Patient                         NaN  2.287200e-05
# Attended Large Gathering                      0.003536  3.612711e-03
# Visited Public Exposed Places                 0.000244  8.232505e-04
# Family working in Public Exposed Places       0.045949  2.048957e-07
#
#                                          Hyper Tension  Fatigue   \
# Breathing Problem                                  NaN       NaN
# Fever                                     2.601633e-02       NaN
# Dry Cough                                 1.728833e-02       NaN
# Sore throat                                        NaN       NaN
# Running Nose                                       NaN       NaN
# Asthma                                             NaN       NaN
# Chronic Lung Disease                               NaN  0.006035
# Headache                                  3.473263e-19  0.021793
# Heart Disease                             1.599943e-02  0.002421
# Diabetes                                  2.182901e-02  0.041136
# Hyper Tension                             0.000000e+00       NaN
# Fatigue                                            NaN  0.000000
# Gastrointestinal                          3.681274e-04       NaN
# Abroad travel                                      NaN  0.004049
# Contact with COVID Patient                         NaN       NaN
# Attended Large Gathering                           NaN       NaN
# Visited Public Exposed Places                      NaN       NaN
# Family working in Public Exposed Places   2.936185e-02       NaN
#
#                                          Gastrointestinal   Abroad travel  \
# Breathing Problem                             8.682145e-03   2.542381e-05
# Fever                                                  NaN   2.440076e-04
# Dry Cough                                              NaN   8.501055e-24
# Sore throat                                            NaN   2.084925e-12
# Running Nose                                           NaN            NaN
# Asthma                                        1.108598e-06   3.379309e-03
# Chronic Lung Disease                          1.797397e-02   5.710013e-05
# Headache                                      8.619310e-06   3.354403e-02
# Heart Disease                                          NaN            NaN
# Diabetes                                      4.642496e-02            NaN
# Hyper Tension                                 4.864892e-04            NaN
# Fatigue                                                NaN   7.054650e-03
# Gastrointestinal                              0.000000e+00   3.124810e-07
# Abroad travel                                 2.026610e-07   0.000000e+00
# Contact with COVID Patient                             NaN   4.201005e-04
# Attended Large Gathering                               NaN   5.106619e-08
# Visited Public Exposed Places                 1.615998e-03   1.029570e-03
# Family working in Public Exposed Places                NaN   3.665719e-13
#
#                                          Contact with COVID Patient  \
# Breathing Problem                                      2.568639e-17
# Fever                                                  6.334264e-07
# Dry Cough                                              1.567136e-04
# Sore throat                                            6.413344e-12
# Running Nose                                                    NaN
# Asthma                                                          NaN
# Chronic Lung Disease                                   8.803607e-03
# Headache                                               1.132794e-05
# Heart Disease                                                   NaN
# Diabetes                                               1.203372e-05
# Hyper Tension                                                   NaN
# Fatigue                                                         NaN
# Gastrointestinal                                                NaN
# Abroad travel                                          1.933509e-04
# Contact with COVID Patient                             0.000000e+00
# Attended Large Gathering                               1.107352e-33
# Visited Public Exposed Places                          1.723095e-03
# Family working in Public Exposed Places                         NaN
#
#                                          Attended Large Gathering  \
# Breathing Problem                                    6.565616e-14
# Fever                                                2.833687e-02
# Dry Cough                                            1.086845e-04
# Sore throat                                          4.493792e-13
# Running Nose                                         1.771443e-02
# Asthma                                               4.249997e-02
# Chronic Lung Disease                                          NaN
# Headache                                             1.797597e-13
# Heart Disease                                        3.437553e-03
# Diabetes                                             3.860426e-03
# Hyper Tension                                                 NaN
# Fatigue                                                       NaN
# Gastrointestinal                                              NaN
# Abroad travel                                        3.195792e-08
# Contact with COVID Patient                           3.273355e-31
# Attended Large Gathering                             0.000000e+00
# Visited Public Exposed Places                        1.564354e-04
# Family working in Public Exposed Places              2.067766e-03
#
#                                          Visited Public Exposed Places  \
# Breathing Problem                                             0.009044
# Fever                                                              NaN
# Dry Cough                                                     0.006755
# Sore throat                                                   0.002450
# Running Nose                                                       NaN
# Asthma                                                             NaN
# Chronic Lung Disease                                          0.000001
# Headache                                                           NaN
# Heart Disease                                                 0.000104
# Diabetes                                                      0.000461
# Hyper Tension                                                      NaN
# Fatigue                                                            NaN
# Gastrointestinal                                              0.000890
# Abroad travel                                                 0.000441
# Contact with COVID Patient                                    0.001497
# Attended Large Gathering                                      0.000067
# Visited Public Exposed Places                                 0.000000
# Family working in Public Exposed Places                            NaN
#
#                                          Family working in Public Exposed Places
# Breathing Problem                                                            NaN
# Fever                                                                        NaN
# Dry Cough                                                           8.943939e-07
# Sore throat                                                         5.533802e-04
# Running Nose                                                        1.478848e-02
# Asthma                                                              9.339544e-08
# Chronic Lung Disease                                                4.152032e-02
# Headache                                                                     NaN
# Heart Disease                                                                NaN
# Diabetes                                                            7.663318e-07
# Hyper Tension                                                       4.099389e-02
# Fatigue                                                                      NaN
# Gastrointestinal                                                             NaN
# Abroad travel                                                       1.530022e-12
# Contact with COVID Patient                                                   NaN
# Attended Large Gathering                                            3.151818e-03
# Visited Public Exposed Places                                                NaN
# Family working in Public Exposed Places                             0.000000e+00

# %% [markdown]
# Breathing problem has a relation between Fever, Dry Cough ,Sore throat,	Running Nose,	Asthma,	Chronic Lung Disease,	Headache,	Heart Disease,	Diabetes,	Hyper Tension,	Gastrointestinal,	Abroad travel,	Contact with COVID Patient,	Attended Large Gathering,	Visited Public Exposed Places

# %% [markdown]
# # Modeling

# %%
xgb.plot_importance(xgbClfr)
plt.rcParams['figure.figsize'] = [5, 5]
plt.show()

# %%
#reduce variables based on variable selection
xnew=x[['Sore throat','Dry Cough','Contact with COVID Patient','Hyper Tension','Breathing Problem','Fever','Heart Disease','Visited Public Exposed Places',
      'Diabetes','Asthma','Running Nose','Headache']]
xnewtest=xtest[['Sore throat','Dry Cough','Contact with COVID Patient','Hyper Tension','Breathing Problem','Fever','Heart Disease','Visited Public Exposed Places',
      'Diabetes','Asthma','Running Nose','Headache']]

# %%
#SVM
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report 

svmClfr=svm.SVC(probability=True).fit(x,y)
svmPred=svmClfr.predict(xtest)
svmAcc=accuracy_score(ytest,svmPred)
conmat = confusion_matrix(ytest, svmPred)
disp = plot_confusion_matrix(svmClfr, xtest, ytest,cmap=plt.cm.Blues)
svmprobs=svmClfr.predict_proba(xtest)
disp.ax_.set_title('Confusion Matrix for SVM Classifier')
print("Accuracy of SVM ")
print(classification_report(ytest, svmPred))
print("Class wise Accuracy ")
print("Class 0 ",(conmat[0][0])/(conmat[0][0]+conmat[0][1]))
print("Class 1 ",(conmat[1][1])/(conmat[1][0]+conmat[1][1]))
# Out:
# Accuracy of SVM
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       219
#            1       0.99      0.99      0.99       868
#
#     accuracy                           0.98      1087
#    macro avg       0.97      0.97      0.97      1087
# weighted avg       0.98      0.98      0.98      1087
#
# Class wise Accuracy
# Class 0  0.9497716894977168
# Class 1  0.9861751152073732

# %%
#ANN
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense

annx=x.to_numpy()
annxtest=xtest.to_numpy()
anny=y.to_numpy()
annytest=ytest.to_numpy()
model = Sequential()
model.add(Dense(22, input_dim=20, activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(annx, anny, epochs=150, batch_size=10)
_, accuracy = model.evaluate(annxtest, annytest)
print('Accuracy: %.2f' % (accuracy*100))
annprobs=model.predict_proba(xtest)
# Out:
# Epoch 1/150
# 435/435 [==============================] - 0s 918us/step - loss: 0.2891 - accuracy: 0.8760
# Epoch 2/150
# 435/435 [==============================] - 0s 977us/step - loss: 0.1109 - accuracy: 0.9637
# Epoch 3/150
# 435/435 [==============================] - 0s 946us/step - loss: 0.0791 - accuracy: 0.9735
# Epoch 4/150
# 435/435 [==============================] - 0s 940us/step - loss: 0.0682 - accuracy: 0.9735
# Epoch 5/150
# 435/435 [==============================] - 0s 927us/step - loss: 0.0604 - accuracy: 0.9768
# Epoch 6/150
# 435/435 [==============================] - 0s 921us/step - loss: 0.0576 - accuracy: 0.9772
# Epoch 7/150
# 435/435 [==============================] - 0s 957us/step - loss: 0.0542 - accuracy: 0.9795
# Epoch 8/150
# 435/435 [==============================] - 0s 936us/step - loss: 0.0504 - accuracy: 0.9784
# Epoch 9/150
# 435/435 [==============================] - 0s 975us/step - loss: 0.0493 - accuracy: 0.9793
# Epoch 10/150
# 435/435 [==============================] - 0s 943us/step - loss: 0.0475 - accuracy: 0.9777
# Epoch 11/150
# 435/435 [==============================] - 0s 952us/step - loss: 0.0475 - accuracy: 0.9788
# Epoch 12/150
# 435/435 [==============================] - 0s 942us/step - loss: 0.0451 - accuracy: 0.9788
# Epoch 13/150
# 435/435 [==============================] - 0s 933us/step - loss: 0.0461 - accuracy: 0.9784
# Epoch 14/150
# 435/435 [==============================] - 0s 972us/step - loss: 0.0432 - accuracy: 0.9793
# Epoch 15/150
# 435/435 [==============================] - 0s 948us/step - loss: 0.0431 - accuracy: 0.9788
# Epoch 16/150
# 435/435 [==============================] - 0s 956us/step - loss: 0.0420 - accuracy: 0.9791
# Epoch 17/150
# 435/435 [==============================] - 0s 946us/step - loss: 0.0405 - accuracy: 0.9795
# Epoch 18/150
# 435/435 [==============================] - 0s 933us/step - loss: 0.0414 - accuracy: 0.9788
# Epoch 19/150
# 435/435 [==============================] - 0s 939us/step - loss: 0.0418 - accuracy: 0.9802
# Epoch 20/150
# Epoch 147/150
# 435/435 [==============================] - 0s 918us/step - loss: 0.0356 - accuracy: 0.9818
# Epoch 148/150
# 435/435 [==============================] - 0s 921us/step - loss: 0.0352 - accuracy: 0.9802
# Epoch 149/150
# 435/435 [==============================] - 0s 930us/step - loss: 0.0358 - accuracy: 0.9802
# Epoch 150/150
# 435/435 [==============================] - 0s 924us/step - loss: 0.0360 - accuracy: 0.9804
# 34/34 [==============================] - 0s 1ms/step - loss: 0.0371 - accuracy: 0.9825
# Accuracy: 98.25

# %%
#visualize ann
from ann_visualizer.visualize import ann_viz;

ann_viz(model, view=True, title="Neural Network for COVID prediction")

# %%
#XGB
import xgboost as xgb
xgbClfr=xgb.XGBClassifier().fit(x,y)
xgbPred=xgbClfr.predict(xtest)
xgbAcc=accuracy_score(ytest,xgbPred)
conmat = confusion_matrix(ytest, xgbPred)
disp = plot_confusion_matrix(xgbClfr, xtest, ytest,cmap=plt.cm.Blues)
disp.ax_.set_title('Confusion Matrix for XGB Classifier')
xgbprobs=xgbClfr.predict_proba(xtest)
print("Accuracy of XGB ")
print(classification_report(ytest, xgbPred))
print("Class wise Accuracy ")
print("Class 0 ",(conmat[0][0])/(conmat[0][0]+conmat[0][1]))
print("Class 1 ",(conmat[1][1])/(conmat[1][0]+conmat[1][1]))
# Out:
# C:\Users\sachi\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [10:24:50] WARNING: ..\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy of XGB
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       219
#            1       0.99      0.99      0.99       868
#
#     accuracy                           0.98      1087
#    macro avg       0.97      0.98      0.97      1087
# weighted avg       0.98      0.98      0.98      1087
#
# Class wise Accuracy
# Class 0  0.9726027397260274
# Class 1  0.9861751152073732

# %%
xgb.plot_tree(xgbClfr,num_trees=0)
plt.show()

# %%
#RF
from sklearn.ensemble import RandomForestClassifier

rfClfr=RandomForestClassifier().fit(x,y)
rfPred=rfClfr.predict(xtest)
rfAcc=accuracy_score(ytest,rfPred)
conmat = confusion_matrix(ytest, rfPred)
disp = plot_confusion_matrix(rfClfr, xtest, ytest,cmap=plt.cm.Blues)
rfprobs=rfClfr.predict_proba(xtest)
disp.ax_.set_title('Confusion Matrix for RF Classifier')
print("Accuracy of RF ")
print(classification_report(ytest, rfPred))
print("Class wise Accuracy ")
print("Class 0 ",(conmat[0][0])/(conmat[0][0]+conmat[0][1]))
print("Class 1 ",(conmat[1][1])/(conmat[1][0]+conmat[1][1]))
# Out:
# Accuracy of RF
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       219
#            1       0.99      0.99      0.99       868
#
#     accuracy                           0.98      1087
#    macro avg       0.97      0.98      0.97      1087
# weighted avg       0.98      0.98      0.98      1087
#
# Class wise Accuracy
# Class 0  0.9726027397260274
# Class 1  0.9861751152073732

# %%
# roc curve and auc
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot

ns_probs = [0 for _ in range(len(ytest))]

svmprobs = svmprobs[:, 1]
rfprobs = rfprobs[:, 1]
#annprobs = annprobs[:, 1]
xgbprobs = xgbprobs[:, 1]


ns_auc = roc_auc_score(ytest, ns_probs)
svm_auc = roc_auc_score(ytest, svmprobs)
rf_auc = roc_auc_score(ytest, rfprobs)
ann_auc = roc_auc_score(ytest, annprobs)
xgb_auc = roc_auc_score(ytest, xgbprobs)

# summarize scores
print('Random Classifier: ROC AUC=%.3f' % (ns_auc))
print('SVM: ROC AUC=%.3f' % (svm_auc))
print('RF: ROC AUC=%.3f' % (rf_auc))
print('ANN: ROC AUC=%.3f' % (ann_auc))
print('XGB: ROC AUC=%.3f' % (xgb_auc))

# calculate roc curves
ns_fpr, ns_tpr, _ = roc_curve(ytest, ns_probs)
lr_fpr, lr_tpr, _ = roc_curve(ytest, svmprobs)
rf_fpr, rf_tpr, _ = roc_curve(ytest, rfprobs)
ann_fpr, ann_tpr, _ = roc_curve(ytest, annprobs)
xgb_fpr, xgb_tpr, _ = roc_curve(ytest, xgbprobs)

# plot the roc curve for the model
pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='Random Classifier')
pyplot.plot(lr_fpr, lr_tpr, marker='.', label='SVM')
pyplot.plot(rf_fpr, rf_tpr, marker='.', label='RF')
pyplot.plot(ann_fpr, ann_tpr, marker='.', label='ANN')
pyplot.plot(xgb_fpr, xgb_tpr, marker='.', label='XGB')


# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# Random Classifier: ROC AUC=0.500
# SVM: ROC AUC=0.994
# RF: ROC AUC=0.998
# ANN: ROC AUC=0.998
# XGB: ROC AUC=0.998

# %% [markdown]
# # Multiple correspondence analysis

# %%
from prince import MCA

newdata=data 
newdata.drop(inplace=True, axis=1,columns='ID')
mca = MCA(n_components = 3, n_iter = 3, random_state = 101)
mca.fit(newdata)
tips_mca = mca.transform(newdata)
tips_mca.head()

# %%
print('Explained Variance ',mca.explained_inertia_)

# %%
plt.figure(figsize=(16,16))

ax=mca.plot_coordinates(newdata,figsize=(6,6))
ax.legend(loc='center right',bbox_to_anchor=(1.75, 0.5))

# %%
ax = plt.figure(figsize=(16,10)).gca(projection='3d')

ax.scatter(
    xs=tips_mca.loc[:,:][0], 
    ys=tips_mca.loc[:,:][1], 
    zs=tips_mca.loc[:,:][2], 
    c=tips_mca[0],
    cmap='Set1'
   
)
ax.set_xlabel('pca-one')
ax.set_ylabel('pca-two')
ax.set_zlabel('pca-three')
plt.show()

# %%
columncord=mca.column_coordinates(data)

# %%
mca1=[]
mca2=[]
mca3=[]
for i in columncord.index:
    if abs(columncord[0][i]) >=0.5:
        mca1.append(i)
    if abs(columncord[1][i]) >=0.5:
        mca2.append(i)
    if abs(columncord[2][i]) >=0.5:
        mca3.append(i)

# %%
print('Variables highle correlated with MCA1 are ,')
for j in mca1:
    print(j)

# %%
print('Variables highle correlated with MCA2 are ,')
for j in mca2:
    print(j)

# %%
print('Variables highle correlated with MCA3 are ,')
for j in mca3:
    print(j)

# %% [markdown]
# # Apply Apriori Algorithm to discover assocaition Rules

# %%
from mlxtend.frequent_patterns import apriori

frequent_itemsets_ap = apriori(x.iloc[:,1:], min_support=0.01, use_colnames=True)

# %%
print(frequent_itemsets_ap)

# %%
frequent_itemsets_ap=frequent_itemsets_ap[frequent_itemsets_ap['support']>0.1]

# %%
from mlxtend.frequent_patterns import association_rules

rules_ap = association_rules(frequent_itemsets_ap, metric="confidence", min_threshold=0.8)
print(rules_ap)

# %%
rules_ap.head()
